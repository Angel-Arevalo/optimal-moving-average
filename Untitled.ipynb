# %%
import find_best

# %%
#find_best.methods = {"SMA", "EMA", "TRIMA"}
find_best.weights = [0.4, 0.4, 0.2, 0]
find_best.best_main("Data_total_US500.csv")
# Out:
# [Categorical(categories=('SMA', 'TRIMA', 'EMA'), prior=None), Integer(low=2, high=110, prior='uniform', transform='identity'), Integer(low=1, high=100, prior='uniform', transform='identity')]
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('SMA'), np.int64(59), np.int64(40)] before, using random point ['EMA', np.int64(105), np.int64(52)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('SMA'), np.int64(59), np.int64(40)] before, using random point ['EMA', np.int64(68), np.int64(95)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('SMA'), np.int64(58), np.int64(40)] before, using random point ['SMA', np.int64(4), np.int64(2)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('SMA'), np.int64(58), np.int64(40)] before, using random point ['SMA', np.int64(98), np.int64(3)]
#   warnings.warn(
# Mejor método  : TRIMA
# Mejor lookback: 65
# Mejor candle  : 40
# Best KPI combo: 0.7732534814199508
# Hit ratio: 0.7469879518072289
# Risk reward: 0.4295507249109178
# Profit ratio: 1.5131900536634602
# # trades: 415

# %%
find_best.weights = [0.3, 0.4, 0.3, 0]
find_best.best_main("Data_total_US500.csv")
# Out:
# [Categorical(categories=('KAMA', 'MIDPOINT', 'TEMA', ..., 'DEMA', 'TRIMA', 'SMA'), prior=None), Integer(low=2, high=110, prior='uniform', transform='identity'), Integer(low=1, high=100, prior='uniform', transform='identity')]
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['KAMA', np.int64(50), np.int64(94)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['TRIMA', np.int64(59), np.int64(17)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['EMA', np.int64(88), np.int64(48)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['TRIMA', np.int64(44), np.int64(46)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['WMA', np.int64(66), np.int64(96)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['TEMA', np.int64(20), np.int64(38)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['DEMA', np.int64(41), np.int64(53)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['WMA', np.int64(27), np.int64(65)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['WMA', np.int64(62), np.int64(87)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['MIDPOINT', np.int64(79), np.int64(22)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['WMA', np.int64(83), np.int64(39)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['MIDPOINT', np.int64(63), np.int64(28)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['T3', np.int64(91), np.int64(68)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['TEMA', np.int64(85), np.int64(30)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('T3'), np.int64(2), np.int64(100)] before, using random point ['DEMA', np.int64(49), np.int64(27)]
#   warnings.warn(
# /home/angel/Documents/moving_averague_op/optimice_venv/lib/python3.13/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('DEMA'), np.int64(2), np.int64(100)] before, using random point ['TRIMA', np.int64(38), np.int64(59)]
#   warnings.warn(
