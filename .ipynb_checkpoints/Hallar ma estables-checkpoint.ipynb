# %%
# lectura de los datos

import pandas as pd
import read_data

# Suponiendo que el activo tiene ese nombre
# solo es remplazar por el nombre que se tenga
# solo se acepta archivos .parquet y .csv
nombre_activo: str = "EURUSD.parquet"
data: pd.DataFrame = read_data.read_asset(nombre_activo)

# %%
ohlc = read_data.ohlc_form(data, "1min")

# %%
import use_tecnics

moving_average = use_tecnics.main("TRIMA", 2, ohlc)

# %%
from rsi_atr_opt import optimizer

print(optimizer.main(ohlc, "rsi", moving_average))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from rsi_atr_opt import optimizer
# ----> 3 print(main(ohlc, "rsi", moving_average))
#
# NameError: name 'main' is not defined
