# %%
# lectura de los datos

import pandas as pd
import read_data

# Suponiendo que el activo tiene ese nombre
# solo es remplazar por el nombre que se tenga
# solo se acepta archivos .parquet y .csv
nombre_activo: str = "EURUSD.parquet"
data: pd.DataFrame = read_data.read_asset(nombre_activo)

primer_lunes = data[data.index.dayofweek == 0].index[0]

data = data[primer_lunes:]

# %%
import find_best
from read_data import ohlc_form
from use_tecnics import main, simple_methods
import keys

keys.methods = simple_methods
keys.candles = 20

comp_sem = pd.Timedelta(days=4)
next_lun = pd.Timedelta(days=3)
ventana_ent = pd.Timedelta(weeks=3) + comp_sem

inicio = data.index[0].date()
fin = data.index[-1].date()

signals_and_prices = None

while True:
    train_time_init = inicio
    train_time_fin = inicio + ventana_ent

    test_time_init = train_time_fin + next_lun
    test_time_fin = test_time_init + comp_sem

    inicio += comp_sem + next_lun
    if inicio >= fin:
        break

    print(f"Etapa de entrenamiento desde {train_time_init} hasta  {train_time_fin}")
    data_w = data.loc[train_time_init: train_time_fin]
    best_ma = find_best.opti_main(data_w)

    data_w = data.loc[train_time_fin - comp_sem: test_time_fin]
    data_w = ohlc_form(data_w, f"{best_ma[1]}min")["close"]

    data_w = main(best_ma[0], data_w, best_ma[2:])
    data_w = data_w.loc[test_time_init: test_time_fin]

    f_index = data_w.index[0]
    l_index = data_w.index[-1]

    if data_w["Signals"][f_index] == -1:
        f_index = data_w["Signals"].index[1]

    if data_w["Signals"][l_index] == 1:
        l_index = data_w["Signals"].index[-2]

    data_w = data_w.loc[f_index: l_index]
    print(f"Guardando etapa de testeo desde {test_time_init} hasta  {test_time_fin}")
    if signals_and_prices is None:
        signals_and_prices = data_w
    else:
        signals_and_prices = pd.concat([signals_and_prices, data_w])
# Out:
# 2025-03-24 2025-03-28
# Etapa de entrenamiento desde 2025-02-24 hasta  2025-03-21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 32
#      30 print(f"Etapa de entrenamiento desde {train_time_init} hasta  {train_time_fin}")
#      31 data_w = data.loc[train_time_init: train_time_fin]
# ---> 32 best_ma = find_best.opti_main(data_w)
#      34 data_w = data.loc[train_time_fin - comp_sem: test_time_fin]
#      35 data_w = ohlc_form(data_w, f"{best_ma[1]}min")["close"]
#
# File ~/Documents/optimal-moving-average/find_best.py:57, in opti_main(data, verbose, engie)
#      53         return -f(hr, rr, pr, tr, sqn)
#      55     return (sqn, hr, rr, pr, tr)
# ---> 57 result: list = optimizer(objective, space, engie)
#      59 if best_result is None:
#      60     best_result = result
#
# File ~/Documents/optimal-moving-average/find_best.py:112, in optimizer(objective, space, engie)
#     103     result = gp_minimize(
#     104                 func=objective,
#     105                 dimensions=space,
#    (...)    108                 random_state=42,
#     109             )
#     111 elif engie == "fm":
# --> 112     result = forest_minimize(
#     113                 func=objective,
#     114                 dimensions=space,
#     115                 n_calls=keys.calls,
#     116                 n_initial_points=10,
#     117                 random_state=0,
#     118                 verbose=False
#     119              )
#     121 else:
#     122     raise ValueError(f"No se reconoce {engie} como Motor")
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/skopt/optimizer/forest.py:203, in forest_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, acq_func, initial_point_generator, x0, y0, random_state, verbose, callback, n_points, xi, kappa, n_jobs, model_queue_size, space_constraint)
#       6 def forest_minimize(
#       7     func,
#       8     dimensions,
#    (...)     25     space_constraint=None,
#      26 ):
#      27     """Sequential optimisation using decision trees.
#      28
#      29     A tree based regression model is used to model the expensive to evaluate
#    (...)    201         :class:`skopt.dummy_minimize`, :class:`skopt.gbrt_minimize`
#     202     """
# --> 203     return base_minimize(
#     204         func,
#     205         dimensions,
#     206         base_estimator,
#     207         n_calls=n_calls,
#     208         n_points=n_points,
#     209         n_random_starts=n_random_starts,
#     210         n_initial_points=n_initial_points,
#     211         initial_point_generator=initial_point_generator,
#     212         x0=x0,
#     213         y0=y0,
#     214         random_state=random_state,
#     215         n_jobs=n_jobs,
#     216         acq_func=acq_func,
#     217         xi=xi,
#     218         kappa=kappa,
#     219         verbose=verbose,
#     220         callback=callback,
#     221         acq_optimizer="sampling",
#     222         space_constraint=space_constraint,
#     223         model_queue_size=model_queue_size,
#     224     )
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/skopt/optimizer/base.py:333, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     331 next_x = optimizer.ask()
#     332 next_y = func(next_x)
# --> 333 result = optimizer.tell(next_x, next_y)
#     334 result.specs = specs
#     335 if eval_callbacks(callbacks, result):
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/skopt/optimizer/optimizer.py:570, in Optimizer.tell(self, x, y, fit)
#     567         y = list(y)
#     568         y[1] = log(y[1])
# --> 570 return self._tell(x, y, fit=fit)
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/skopt/optimizer/optimizer.py:615, in Optimizer._tell(self, x, y, fit)
#     613 with warnings.catch_warnings():
#     614     warnings.simplefilter("ignore")
# --> 615     est.fit(self.space.transform(self.Xi), self.yi)
#     617 if hasattr(self, "next_xs_") and self.acq_func == "gp_hedge":
#     618     self.gains_ -= est.predict(np.vstack(self.next_xs_))
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/ensemble/_forest.py:196, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     188     tree._fit(
#     189         X,
#     190         y,
#    (...)    193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
# --> 196     tree._fit(
#     197         X,
#     198         y,
#     199         sample_weight=sample_weight,
#     200         check_input=False,
#     201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#     204 return tree
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/tree/_classes.py:447, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     445     self.tree_ = Tree(self.n_features_in_, self.n_classes_, self.n_outputs_)
#     446 else:
# --> 447     self.tree_ = Tree(
#     448         self.n_features_in_,
#     449         # TODO: tree shouldn't need this in this case
#     450         np.array([1] * self.n_outputs_, dtype=np.intp),
#     451         self.n_outputs_,
#     452     )
#     454 # Use BestFirst if max_leaf_nodes given; use DepthFirst otherwise
#     455 if max_leaf_nodes < 0:
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/sklearn/tree/_tree.pyx:784, in sklearn.tree._tree.Tree.__cinit__()
#
# File ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:3006, in _max_dispatcher(a, axis, out, keepdims, initial, where)
#    3002         kwargs['keepdims'] = keepdims
#    3003     return _methods._ptp(a, axis=axis, out=out, **kwargs)
# -> 3006 def _max_dispatcher(a, axis=None, out=None, keepdims=None, initial=None,
#    3007                     where=None):
#    3008     return (a, out)
#    3011 @array_function_dispatch(_max_dispatcher)
#    3012 @set_module('numpy')
#    3013 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3014          where=np._NoValue):
#
# KeyboardInterrupt:

# %%
signals_and_prices.to_parquet("Data/señales_periodo_completo.parquet")

# %%
signals_and_prices = pd.read_parquet("Data/señales_periodo_completo.parquet")
signals_and_prices
# Out:
#                      Signals    Prices
# time
# 2025-03-24 00:00:00        1  1.081470
# 2025-03-24 02:40:00       -1  1.083565
# 2025-03-24 04:16:00        1  1.082750
# 2025-03-24 09:04:00       -1  1.083590
# 2025-03-24 12:00:00        1  1.083450
# ...                      ...       ...
# 2025-12-23 18:56:00        1  1.177560
# 2025-12-23 20:48:00       -1  1.178470
# 2025-12-24 10:08:00        1  1.178450
# 2025-12-24 10:24:00       -1  1.178915
# 2025-12-24 13:52:00        1  1.179060
#
# [1082 rows x 2 columns]

# %%
from tester import backtest

backtest(signals_and_prices, False)
# Out:
# (np.float64(0.7941176470588235),
#  np.float64(0.7041938997821516),
#  np.float64(2.716176470588299),
#  34)

# %%
initial_mon = 1000
cantidad = 0

for index in signals_and_prices.index:
    precio_actual = signals_and_prices["Prices"][index]
    current_signal = signals_and_prices["Signals"][index]

    print("Inicia con", initial_mon)
    if current_signal == 1 and cantidad == 0:
        cantidad = int(initial_mon / precio_actual)

        initial_mon -= (precio_actual * cantidad) 

    elif current_signal == -1 and cantidad > 0:

        initial_mon += (precio_actual * cantidad) 
        cantidad = 0

    print("Termina con", initial_mon)
# Out:
# Inicia con 1000
# Termina con 0.3059200000000146
# Inicia con 0.3059200000000146
# Termina con 1000.0831599999999
# Inicia con 1000.0831599999999
# Termina con 1.0741100000000188
# Inicia con 1.0741100000000188
# Termina con 1000.7292600000001
# Inicia con 1000.7292600000001
# Termina con 0.36990000000002965
# Inicia con 0.36990000000002965
# Termina con 1000.86786
# Inicia con 1000.86786
# Termina con 0.887339999999881
# Inicia con 0.887339999999881
# Termina con 1001.31138
# Inicia con 1001.31138
# Termina con 0.2035799999999881
# Inicia con 0.2035799999999881
# Termina con 1001.5146599999999
# Inicia con 1001.5146599999999
# Termina con 0.9427799999999706
# Inicia con 0.9427799999999706
# Termina con 998.6225399999998
# Inicia con 998.6225399999998
# Termina con 0.6748199999998405
# Inicia con 0.6748199999998405
# Termina con 999.3617399999998
# Inicia con 999.3617399999998
# Termina con 0.1998649999997042
# Inicia con 0.1998649999997042
# Termina con 999.1351149999997
# Inicia con 999.1351149999997
# Termina con 0.5791149999996605
# Inicia con 0.5791149999996605
# Termina con 999.5837399999996
# Inicia con 999.5837399999996
# Termina con 0.5686399999995047
# Inicia con 0.5686399999995047
# Termina con 1000.1485999999995
# Inicia con 1000.1485999999995
# Termina con 0.26785999999958676
# Inicia con 0.26785999999958676
# Termina con 1000.6862599999995
# Inicia con 1000.6862599999995
# Termina con 1.0465399999994816
# Inicia con 1.0465399999994816
# Termina con 1000.8901999999996
# Inicia con 1000.8901999999996
# Termina con 0.598999999999478
# Inicia con 0.598999999999478
# Termina con 1001.7346799999996
# Inicia con 1001.7346799999996
# Termina con 0.4677699999995184
# Inicia con 0.4677699999995184
# Termina con 1000.9264499999996
# Inicia con 1000.9264499999996
# Termina con 0.4192499999995789
# Inicia con 0.4192499999995789
# Termina con 1000.2935099999995
# Inicia con 1000.2935099999995
# Termina con 0.7103099999994811
# Inicia con 0.7103099999994811
# Termina con 1000.7185499999995
# Inicia con 1000.7185499999995
# Termina con 0.4053899999995565
# Inicia con 0.4053899999995565
# Termina con 1001.1897899999996
# Inicia con 1001.1897899999996
# Termina con 0.043789999999603424
# Inicia con 0.043789999999603424
# Termina con 1001.8280399999996
# Inicia con 1001.8280399999996
# Termina con 0.7837899999997262
# Inicia con 0.7837899999997262
# Termina con 1002.3136649999997
# Inicia con 1002.3136649999997
# Termina con 0.7976649999997107
# Inicia con 0.7976649999997107
# Termina con 1001.5459149999997
# Inicia con 1001.5459149999997
# Termina con 0.9734149999995907
# Inicia con 0.9734149999995907
# Termina con 1001.7586649999996
# Inicia con 1001.7586649999996
# Termina con 0.2711449999995921
# Inicia con 0.2711449999995921
# Termina con 1002.1938849999996
# Inicia con 1002.1938849999996
# Termina con 0.5981949999995777
# Inicia con 0.5981949999995777
# Termina con 1002.6573849999995
# Inicia con 1002.6573849999995
# Termina con 0.26447499999960655
# Inicia con 0.26447499999960655
# Termina con 1002.2587749999996
# Inicia con 1002.2587749999996
# Termina con 0.9411849999994502
# Inicia con 0.9411849999994502
# Termina con 1002.9540249999995
# Inicia con 1002.9540249999995
# Termina con 0.4263449999994009
# Inicia con 0.4263449999994009
# Termina con 1003.2509849999993
# Inicia con 1003.2509849999993
# Termina con 0.565544999999247
# Inicia con 0.565544999999247
# Termina con 1002.6849049999994
# Inicia con 1002.6849049999994
# Termina con 0.8439449999995077
# Inicia con 0.8439449999995077
# Termina con 1002.7034649999996
# Inicia con 1002.7034649999996
# Termina con 0.9274649999996427
# Inicia con 0.9274649999996427
# Termina con 1002.8241049999997
# Inicia con 1002.8241049999997
# Termina con 0.19156499999962762
# Inicia con 0.19156499999962762
# Termina con 1003.2978949999996
# Inicia con 1003.2978949999996
# Termina con 0.8047049999995579
# Inicia con 0.8047049999995579
# Termina con 1003.8645849999996
# Inicia con 1003.8645849999996
# Termina con 0.4797849999997652
# Inicia con 0.4797849999997652
# Termina con 1007.2249599999998
# Inicia con 1007.2249599999998
# Termina con 0.0598499999998694
# Inicia con 0.0598499999998694
# Termina con 1008.50974
# Inicia con 1008.50974
# Termina con 0.7661000000000513
# Inicia con 0.7661000000000513
# Termina con 1010.8350800000002
# 0.0
