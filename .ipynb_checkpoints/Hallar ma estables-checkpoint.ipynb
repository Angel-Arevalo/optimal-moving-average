# %%
# lectura de los datos

import pandas as pd
import read_data

# Suponiendo que el activo tiene ese nombre
# solo es remplazar por el nombre que se tenga
# solo se acepta archivos .parquet y .csv
nombre_activo: str = "EURUSD_2019-2025.parquet"
data: pd.DataFrame = pd.read_parquet(f"Data/{nombre_activo}")

primer_lunes = data[data.index.dayofweek == 0].index[0]
ultimo_viernes = data[data.index.dayofweek == 4].index[-1]

data = data.loc[primer_lunes: ultimo_viernes]
data = data.between_time('07:00', '16:00')
data
# Out:
#                      Precio Spot
# time
# 2019-01-07 07:00:00     1.142020
# 2019-01-07 07:01:00     1.142060
# 2019-01-07 07:02:00     1.142060
# 2019-01-07 07:03:00     1.142180
# 2019-01-07 07:04:00     1.142170
# ...                          ...
# 2026-02-13 15:56:00     1.187810
# 2026-02-13 15:57:00     1.187695
# 2026-02-13 15:58:00     1.187485
# 2026-02-13 15:59:00     1.187420
# 2026-02-13 16:00:00     1.187060
#
# [1052237 rows x 1 columns]

# %%
import numpy as np
import pandas as pd

ma_week = []

with open("Data/Moving_average_test.txt", "r") as archivo:

    for line in archivo:
        start = pd.Timestamp(line[:10])
        fin = pd.Timestamp(line[11:21])

        lista = eval(line[22: ], {"np": np})

        ma_week.append([start, fin, lista])

# %%
import train_network

X, y = train_network.build_weekly_dataset(data, ma_week)
# Out:
# Calculando matemáticas avanzadas para timeframe 13min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 11min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 12min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 14min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 19min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 8min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 15min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 16min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 4min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 10min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 5min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 20min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 3min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 17min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 1min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 9min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 2min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 18min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 7min (solo se hace una vez)...
# Calculando matemáticas avanzadas para timeframe 6min (solo se hace una vez)...

# %%
import train_network

model = train_network.train_model(X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.60      0.63      6852
#            1       0.64      0.70      0.67      7034
#
#     accuracy                           0.65     13886
#    macro avg       0.65      0.65      0.65     13886
# weighted avg       0.65      0.65      0.65     13886

# %%
import joblib

nombre_archivo = "modelo_filtro_ma.joblib"
joblib.dump(model, nombre_archivo)

print(f"¡Modelo guardado exitosamente como {nombre_archivo}!")
# Out:
# ¡Modelo guardado exitosamente como modelo_filtro_ma.joblib!

# %%
import joblib

model = joblib.load("modelo_filtro_ma.joblib")

# %%
from tester import backtest
from use_tecnics import main

def get_info_in_week(data: pd.DataFrame, week: list) -> pd.DataFrame:
    time_col = week[0] - pd.Timedelta(weeks=1)

    data_week_raw = data.loc[time_col: week[1]]

    velas_cerradas = read_data.ohlc_form(
        data_week_raw,
        f"{week[2][1]}min"
    )["close"]

    method_name = week[2][0]
    params = week[2][2]

    df_week = main(method_name, velas_cerradas, params)

    df_week = df_week.loc[week[0]: week[1]]

    if len(df_week) == 0:
        return pd.DataFrame()

    return df_week

def get_signals_and_prices(data: pd.DataFrame, ma_week: list) -> pd.DataFrame:
    signals_and_prices = []

    for week in ma_week:
        data_week = get_info_in_week(data, week)

        if len(data_week) == 0:
            continue

        f_i = data_week.index[0]
        l_i = data_week.index[-1]

        if data_week["Signals"][f_i] == -1:
            f_i = data_week.index[1]

        if data_week["Signals"][l_i] == 1:
            l_i = data_week.index[-2]

        data_week = data_week.loc[f_i: l_i]
        
        signals_and_prices.append(data_week)

    if len(signals_and_prices) == 0:
        return pd.DataFrame()

    signals_and_prices = pd.concat(signals_and_prices)

    signals_and_prices = signals_and_prices.sort_index()
    signals_and_prices = signals_and_prices[~signals_and_prices.index.duplicated()]

    return signals_and_prices.loc[f_i: l_i]

signals_and_prices_c = get_signals_and_prices(data, ma_week)
backtest(signals_and_prices_c, True)
# Out:
# (np.float64(1.0), 0.0, 0.0, 5)

# %%
signals_and_prices_c
# Out:
#                      Signals    Prices
# time
# 2026-03-04 10:00:00        1  1.160510
# 2026-03-04 11:00:00       -1  1.161470
# 2026-03-04 11:40:00        1  1.160870
# 2026-03-04 12:00:00       -1  1.163350
# 2026-03-05 07:00:00        1  1.160930
# 2026-03-05 11:00:00       -1  1.162675
# 2026-03-05 11:20:00        1  1.161660
# 2026-03-05 11:40:00       -1  1.162270
# 2026-03-05 12:20:00        1  1.161230
# 2026-03-05 14:20:00       -1  1.162290

# %%
from train_network import filter_signals_with_ml

signals_and_prices = filter_signals_with_ml(signals_and_prices_c, data, model, umbral=.6)

# %%
backtest(signals_and_prices)
# Out:
# (np.float64(0.8461538461538461),
#  np.float64(0.5079688586267431),
#  np.float64(2.869337606837549),
#  247)

# %%
signals_and_prices = signals_and_prices.loc[signals_and_prices["Signals"] != 0]
signals_and_prices = signals_and_prices.loc[signals_and_prices["Signals"] != signals_and_prices["Signals"].shift(1)]
signals_and_prices
# Out:
#                      Signals    Prices
# time
# 2025-04-02 23:24:00        1  1.083615
# 2025-04-02 23:51:00       -1  1.086025
# 2025-04-03 00:09:00        1  1.082920
# 2025-04-03 02:06:00       -1  1.085520
# 2025-04-03 18:36:00        1  1.104500
# ...                      ...       ...
# 2026-02-11 09:52:00       -1  1.191690
# 2026-02-11 17:06:00        1  1.185830
# 2026-02-11 18:16:00       -1  1.187020
# 2026-02-12 18:04:00        1  1.186730
# 2026-02-12 19:14:00       -1  1.187260
#
# [494 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

def simular_trading_basico(señales_precios, capital_inicial=10000.0, valor_pip=0.0001):
    compradas = 0
    capital_operativo = capital_inicial

    pico_maximo = capital_inicial
    max_drawdown = 0.0
    
    for idx in señales_precios.index:
        precio_actual = señales_precios["Prices"][idx]
        senal = señales_precios["Signals"][idx]

        if senal == 1:
            precio_compra = precio_actual + valor_pip
            if capital_operativo >= precio_compra:
                nuevas_compras = int(capital_operativo / precio_compra)
                compradas += nuevas_compras
                capital_operativo -= nuevas_compras * precio_compra

        elif senal == -1: 
            precio_venta = precio_actual - valor_pip
            capital_operativo += compradas * precio_venta
            compradas = 0
                
        patrimonio_actual = capital_operativo + (compradas * precio_actual)

        if patrimonio_actual > pico_maximo:
            pico_maximo = patrimonio_actual
            
        drawdown_actual = (pico_maximo - patrimonio_actual) / pico_maximo
        
        if drawdown_actual > max_drawdown:
            max_drawdown = drawdown_actual

    print(f"--- RESULTADOS DEL SIMULADOR (INTERÉS COMPUESTO) ---")
    print(f"Patrimonio Total Final: ${patrimonio_actual:.2f}")
    print(f"Capital Inicial: ${capital_inicial:.2f}")
    print(f"Beneficio Neto: ${(patrimonio_actual - capital_inicial):.2f}")
    print(f"Max Drawdown: {max_drawdown * 100:.2f}%\n")
    
    return patrimonio_actual, max_drawdown

simular_trading_basico(signals_and_prices_c)
#simular_trading_basico(signals_and_prices)
print("")
# Out:
# --- RESULTADOS DEL SIMULADOR (INTERÉS COMPUESTO) ---
# Patrimonio Total Final: $10050.52
# Capital Inicial: $10000.00
# Beneficio Neto: $50.52
# Max Drawdown: 0.01%

# %%
import pandas as pd
import find_best
import keys
from use_tecnics import simple_methods

keys.methods = simple_methods
keys.candles = 20
keys.calls = 20

dias_comp_sem = pd.Timedelta(days=4)
next_lun = pd.Timedelta(days=3)
ventana_ent = pd.Timedelta(weeks=3) + dias_comp_sem

primer_lunes = data[data.index.dayofweek == 0].index[0]
ultimo_viernes = data[data.index.dayofweek == 4].index[-1]

inicio_actual = primer_lunes

with open("Data/Moving_average_test.txt", "w") as archivo:
    archivo.write("") 

while True:
    train_time_init = inicio_actual
    train_time_fin = inicio_actual + ventana_ent

    test_time_init = train_time_fin + next_lun
    test_time_fin = test_time_init + dias_comp_sem

    if train_time_fin >= ultimo_viernes:
        break

    print(f"Optimizando ventana: {train_time_init.date()} al {train_time_fin.date()}")

    data_w = data.loc[train_time_init : train_time_fin]
    
    if len(data_w) < 100:
        inicio_actual += (dias_comp_sem + next_lun)
        continue

    best_ma = find_best.opti_main(data_w)

    with open("Data/Moving_average_test.txt", "a") as archivo:
        archivo.write(f"{test_time_init.date()} {test_time_fin.date()}, {best_ma}\n")

    inicio_actual += (dias_comp_sem + next_lun)
# Out:
# Optimizando ventana: 2019-01-07 al 2019-02-01
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(11), np.int64(85)]
# Score: 0.2792
# Sharpe: 0.2852
# Retorno medio: 0.000473
# Volatilidad: 0.001660
# Trades: 30
# Optimizando ventana: 2019-01-14 al 2019-02-08
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(19), np.int64(99)]
# Score: 0.4292
# Sharpe: 0.4332
# Retorno medio: 0.000686
# Volatilidad: 0.001582
# Trades: 20
# Optimizando ventana: 2019-01-21 al 2019-02-15
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TRIMA
# Params: [np.int64(14), np.int64(72)]
# Score: 0.2127
# Sharpe: 0.2183
# Retorno medio: 0.000511
# Volatilidad: 0.002341
# Trades: 28
# Optimizando ventana: 2019-01-28 al 2019-02-22
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(14), np.int64(71)]
# Score: 0.2637
# Sharpe: 0.2683
# Retorno medio: 0.000612
# Volatilidad: 0.002280
# Trades: 23
# Optimizando ventana: 2019-02-04 al 2019-03-01
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(12), np.int64(92)]
# Score: 0.1274
# Sharpe: 0.1316
# Retorno medio: 0.000244
# Volatilidad: 0.001853
# Trades: 21
# Optimizando ventana: 2019-02-11 al 2019-03-08
#
# =========================
# RESULTADO FINAL
# =========================
# Método: KAMA
# Params: [np.int64(20), np.int64(109)]
# Score: 0.2814
# Sharpe: 0.2864
# Retorno medio: 0.000296
# Volatilidad: 0.001033
# Trades: 25
# Optimizando ventana: 2019-02-18 al 2019-03-15
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TEMA
# Params: [np.int64(20), np.int64(109)]
# Score: 0.2033
# Sharpe: 0.2087
# Retorno medio: 0.000218
# Volatilidad: 0.001045
# Trades: 27
# Optimizando ventana: 2019-02-25 al 2019-03-22
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(11), np.int64(61)]
# Score: 0.2832
# Sharpe: 0.2892
# Retorno medio: 0.000442
# Volatilidad: 0.001528
# Trades: 30
# Optimizando ventana: 2019-03-04 al 2019-03-29
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(14), np.int64(51)]
# Score: 0.0883
# Sharpe: 0.0945
# Retorno medio: 0.000190
# Volatilidad: 0.002011
# Trades: 31
# Optimizando ventana: 2019-03-11 al 2019-04-05
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(13), np.int64(54)]
# Score: -0.0488
# Sharpe: -0.0422
# Retorno medio: -0.000079
# Volatilidad: 0.001865
# Trades: 33
# Optimizando ventana: 2019-03-18 al 2019-04-12
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(8), np.int64(63)]
# Score: -0.1323
# Sharpe: -0.1175
# Retorno medio: -0.000152
# Volatilidad: 0.001296
# Trades: 74
# Optimizando ventana: 2019-03-25 al 2019-04-19
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(15), np.int64(88)]
# Score: -0.0964
# Sharpe: -0.0898
# Retorno medio: -0.000106
# Volatilidad: 0.001184
# Trades: 33
# Optimizando ventana: 2019-04-01 al 2019-04-26
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(20), np.int64(105)]
# Score: 0.0717
# Sharpe: 0.0757
# Retorno medio: 0.000102
# Volatilidad: 0.001341
# Trades: 20
# Optimizando ventana: 2019-04-08 al 2019-05-03
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(18), np.int64(60)]
# Score: -0.1560
# Sharpe: -0.1486
# Retorno medio: -0.000247
# Volatilidad: 0.001659
# Trades: 37
# Optimizando ventana: 2019-04-15 al 2019-05-10
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TEMA
# Params: [np.int64(19), np.int64(110)]
# Score: 0.0380
# Sharpe: 0.0426
# Retorno medio: 0.000067
# Volatilidad: 0.001581
# Trades: 23
# Optimizando ventana: 2019-04-22 al 2019-05-17
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(15), np.int64(57)]
# Score: 0.0644
# Sharpe: 0.0688
# Retorno medio: 0.000099
# Volatilidad: 0.001445
# Trades: 22
# Optimizando ventana: 2019-04-29 al 2019-05-24
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(14), np.int64(103)]
# Score: 0.0101
# Sharpe: 0.0131
# Retorno medio: 0.000020
# Volatilidad: 0.001528
# Trades: 15
# Optimizando ventana: 2019-05-06 al 2019-05-31
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(20), np.int64(80)]
# Score: 0.1011
# Sharpe: 0.1065
# Retorno medio: 0.000106
# Volatilidad: 0.000994
# Trades: 27
# Optimizando ventana: 2019-05-13 al 2019-06-07
#
# =========================
# RESULTADO FINAL
# =========================
# Método: DEMA
# Params: [np.int64(19), np.int64(99)]
# Score: 0.1898
# Sharpe: 0.1942
# Retorno medio: 0.000317
# Volatilidad: 0.001632
# Trades: 22
# Optimizando ventana: 2019-05-20 al 2019-06-14
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(15), np.int64(92)]
# Score: 0.4164
# Sharpe: 0.4206
# Retorno medio: 0.000671
# Volatilidad: 0.001596
# Trades: 21
# Optimizando ventana: 2019-05-27 al 2019-06-21
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(16), np.int64(38)]
# Score: 0.2350
# Sharpe: 0.2400
# Retorno medio: 0.000507
# Volatilidad: 0.002113
# Trades: 25
# Optimizando ventana: 2019-06-03 al 2019-06-28
#
# =========================
# RESULTADO FINAL
# =========================
# Método: SMA
# Params: [np.int64(11), np.int64(107)]
# Score: 0.2622
# Sharpe: 0.2676
# Retorno medio: 0.000500
# Volatilidad: 0.001868
# Trades: 27
# Optimizando ventana: 2019-06-10 al 2019-07-05
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TRIMA
# Params: [np.int64(19), np.int64(71)]
# Score: 0.1635
# Sharpe: 0.1693
# Retorno medio: 0.000234
# Volatilidad: 0.001379
# Trades: 29
# Optimizando ventana: 2019-06-17 al 2019-07-12
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TEMA
# Params: [np.int64(16), np.int64(95)]
# Score: 0.1782
# Sharpe: 0.1848
# Retorno medio: 0.000168
# Volatilidad: 0.000909
# Trades: 33
# Optimizando ventana: 2019-06-24 al 2019-07-19
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TEMA
# Params: [np.int64(16), np.int64(103)]
# Score: -0.0160
# Sharpe: -0.0106
# Retorno medio: -0.000017
# Volatilidad: 0.001579
# Trades: 27
# Optimizando ventana: 2019-07-01 al 2019-07-26
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(20), np.int64(72)]
# Score: -0.1014
# Sharpe: -0.0966
# Retorno medio: -0.000208
# Volatilidad: 0.002149
# Trades: 24
# Optimizando ventana: 2019-07-08 al 2019-08-02
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(13), np.int64(33)]
# Score: -0.0242
# Sharpe: -0.0174
# Retorno medio: -0.000032
# Volatilidad: 0.001832
# Trades: 34
# Optimizando ventana: 2019-07-15 al 2019-08-09
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TRIMA
# Params: [np.int64(12), np.int64(101)]
# Score: 0.2819
# Sharpe: 0.2869
# Retorno medio: 0.000462
# Volatilidad: 0.001612
# Trades: 25
# Optimizando ventana: 2019-07-22 al 2019-08-16
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(14), np.int64(110)]
# Score: 0.4977
# Sharpe: 0.5021
# Retorno medio: 0.000559
# Volatilidad: 0.001114
# Trades: 22
# Optimizando ventana: 2019-07-29 al 2019-08-23
#
# =========================
# RESULTADO FINAL
# =========================
# Método: SMA
# Params: [np.int64(19), np.int64(31)]
# Score: 0.1864
# Sharpe: 0.1926
# Retorno medio: 0.000176
# Volatilidad: 0.000914
# Trades: 31
# Optimizando ventana: 2019-08-05 al 2019-08-30
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(16), np.int64(83)]
# Score: 0.1229
# Sharpe: 0.1269
# Retorno medio: 0.000269
# Volatilidad: 0.002118
# Trades: 20
# Optimizando ventana: 2019-08-12 al 2019-09-06
#
# =========================
# RESULTADO FINAL
# =========================
# Método: SMA
# Params: [np.int64(9), np.int64(33)]
# Score: -0.0054
# Sharpe: 0.0072
# Retorno medio: 0.000010
# Volatilidad: 0.001365
# Trades: 63
# Optimizando ventana: 2019-08-19 al 2019-09-13
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(18), np.int64(100)]
# Score: 0.1445
# Sharpe: 0.1491
# Retorno medio: 0.000411
# Volatilidad: 0.002753
# Trades: 23
# Optimizando ventana: 2019-08-26 al 2019-09-20
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TRIMA
# Params: [np.int64(13), np.int64(74)]
# Score: 0.0672
# Sharpe: 0.0718
# Retorno medio: 0.000193
# Volatilidad: 0.002684
# Trades: 23
# Optimizando ventana: 2019-09-02 al 2019-09-27
#
# =========================
# RESULTADO FINAL
# =========================
# Método: MIDPOINT
# Params: [np.int64(18), np.int64(91)]
# Score: 0.1146
# Sharpe: 0.1196
# Retorno medio: 0.000272
# Volatilidad: 0.002272
# Trades: 25
# Optimizando ventana: 2019-09-09 al 2019-10-04
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(15), np.int64(106)]
# Score: 0.0005
# Sharpe: 0.0049
# Retorno medio: 0.000015
# Volatilidad: 0.003039
# Trades: 22
# Optimizando ventana: 2019-09-16 al 2019-10-11
#
# =========================
# RESULTADO FINAL
# =========================
# Método: T3
# Params: [np.int64(13), np.int64(32)]
# Score: 0.0381
# Sharpe: 0.0463
# Retorno medio: 0.000064
# Volatilidad: 0.001373
# Trades: 41
# Optimizando ventana: 2019-09-23 al 2019-10-18
#
# =========================
# RESULTADO FINAL
# =========================
# Método: SMA
# Params: [np.int64(17), np.int64(54)]
# Score: 0.1881
# Sharpe: 0.1967
# Retorno medio: 0.000225
# Volatilidad: 0.001146
# Trades: 43
# Optimizando ventana: 2019-09-30 al 2019-10-25
#
# =========================
# RESULTADO FINAL
# =========================
# Método: EMA
# Params: [np.int64(17), np.int64(101)]
# Score: 0.4995
# Sharpe: 0.5035
# Retorno medio: 0.000417
# Volatilidad: 0.000828
# Trades: 20
# Optimizando ventana: 2019-10-07 al 2019-11-01
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(20), np.int64(70)]
# Score: 0.3212
# Sharpe: 0.3268
# Retorno medio: 0.000383
# Volatilidad: 0.001174
# Trades: 28
# Optimizando ventana: 2019-10-14 al 2019-11-08
#
# =========================
# RESULTADO FINAL
# =========================
# Método: TRIMA
# Params: [np.int64(8), np.int64(88)]
# Score: 0.1146
# Sharpe: 0.1242
# Retorno medio: 0.000182
# Volatilidad: 0.001466
# Trades: 48
# Optimizando ventana: 2019-10-21 al 2019-11-15
#
# =========================
# RESULTADO FINAL
# =========================
# Método: WMA
# Params: [np.int64(17), np.int64(92)]
# Score: -0.0447
# Sharpe: -0.0401
# Retorno medio: -0.000088
# Volatilidad: 0.002204
# Trades: 23
# Optimizando ventana: 2019-10-28 al 2019-11-22
