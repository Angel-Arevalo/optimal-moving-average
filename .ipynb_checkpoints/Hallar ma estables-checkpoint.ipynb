# %%
# lectura de los datos

import pandas as pd
import read_data

# Suponiendo que el activo tiene ese nombre
# solo es remplazar por el nombre que se tenga
# solo se acepta archivos .parquet y .csv
nombre_activo: str = "EURUSD.parquet"
data: pd.DataFrame = read_data.read_asset(nombre_activo)

primer_lunes = data[data.index.dayofweek == 0].index[0]

data = data[primer_lunes:]

# %%
import numpy as np
import pandas as pd

ma_week = []

with open("Data/Moving_average.txt", "r") as archivo:

    for line in archivo:
        start = pd.Timestamp(line[:10])
        fin = pd.Timestamp(line[11:21])

        lista = eval(line[22: -1], {"np": np})

        ma_week.append([start, fin, lista])

# %%
import train_network

fetures = train_network.get_fetures(data, ma_week)

# %%
fetures
# Out:
#            Fecha_Señal  Precio_Entrada  MA_Entrada  FFT_Score    Concavidad  \
# 0  2025-03-24 01:20:00         1.08192    1.081960   0.071001  2.892012e-07
# 0  2025-03-24 04:32:00         1.08235    1.082653   0.193166  1.236639e-06
# 0  2025-03-24 05:36:00         1.08264    1.082653   0.223458  1.100319e-06
# 0  2025-03-24 06:40:00         1.08223    1.082653   0.272827  8.481702e-07
# 0  2025-03-24 12:00:00         1.08345    1.083473   0.161359  2.815483e-07
# ..                 ...             ...         ...        ...           ...
# 0  2026-02-18 09:36:00         1.18340    1.183636   0.250527 -2.519270e-06
# 0  2026-02-18 11:12:00         1.18339    1.183614   0.217236 -2.157285e-06
# 0  2026-02-18 12:32:00         1.18359    1.183609   0.285053 -1.146918e-06
# 0  2026-02-18 13:52:00         1.18348    1.183601   0.276008 -4.699199e-07
# 0  2026-02-18 15:28:00         1.18328    1.183617   0.286947  3.590828e-07
#
#        Pendiente     Sesgo   Curtosis  Area_Separacion  Target_Velas  \
# 0  -1.449258e-05  3.571662  23.896597         0.001235             1
# 0  -5.471011e-05  1.271425   7.051646         0.008649             0
# 0  -4.197287e-05  1.035628   4.103767         0.009049             0
# 0  -2.296135e-05  0.917132   3.527035         0.009629             2
# 0   2.876074e-05  0.557145   2.751190         0.019611             1
# ..           ...       ...        ...              ...           ...
# 0   1.918084e-04 -0.390279   2.491857         0.056482             4
# 0   1.405744e-04  0.623888   2.169206         0.065547             1
# 0   5.513938e-05 -0.137558   0.511546         0.066834             1
# 0   3.272785e-07 -0.128632   0.965374         0.061528             0
# 0  -5.285181e-05 -0.048061   0.624471         0.054139            31
#
#         Tramo_ID
# 0   2025-03-24_0
# 0   2025-03-24_1
# 0   2025-03-24_2
# 0   2025-03-24_3
# 0   2025-03-24_4
# ..           ...
# 0   2026-02-16_4
# 0   2026-02-16_5
# 0   2026-02-16_6
# 0   2026-02-16_7
# 0   2026-02-16_8
#
# [627 rows x 11 columns]

# %%
modelo, escalador, caracteristicas = train_network.train_target_velas_model(fetures)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4148/106574256.py in ?()
# ----> 1 modelo, escalador, caracteristicas = train_network.train_target_velas_model(fetures)
#
# ~/Documents/optimal-moving-average/train_network.py in ?(df_ml)
#     165         'Precio_Entrada', 'MA_Entrada', 'FFT_Score',
#     166         'Concavidad', 'Pendiente', 'Sesgo', 'Curtosis', 'Area_Separacion'
#     167     ]
#     168
# --> 169     df_clean = df_ml.dropna(subset=columnas_x + ['Target_Velas'])
#     170
#     171     X = df_clean[columnas_x]
#     172     y = df_clean['Target_Velas']
#
# ~/Documents/optimal-moving-average/opt_m/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    7785             ax = self._get_axis(agg_axis)
#    7786             indices = ax.get_indexer_for(subset)
#    7787             check = indices == -1
#    7788             if check.any():
# -> 7789                 raise KeyError(np.array(subset)[check].tolist())
#    7790             agg_obj = self.take(indices, axis=agg_axis)
#    7791
#    7792         if thresh is not lib.no_default:
#
# KeyError: ['Precio_Entrada', 'MA_Entrada']

# %%
import find_best
from read_data import ohlc_form
from use_tecnics import main, simple_methods
import keys

keys.methods = simple_methods
keys.candles = 20

comp_sem = pd.Timedelta(days=4)
next_lun = pd.Timedelta(days=3)
ventana_ent = pd.Timedelta(weeks=3) + comp_sem

inicio = data.index[0].date()
fin = data.index[-1].date()

while True:
    train_time_init = inicio
    train_time_fin = inicio + ventana_ent

    test_time_init = train_time_fin + next_lun
    test_time_fin = test_time_init + comp_sem

    inicio += comp_sem + next_lun
    if inicio >= fin:
        break

    print(f"Etapa de entrenamiento desde {train_time_init} hasta  {train_time_fin}")
    data_w = data.loc[train_time_init: train_time_fin]
    best_ma = find_best.opti_main(data_w)

    with open("Data/Moving_average.txt", "a") as archivo:
        archivo.write(f"{test_time_init} {test_time_fin}, {best_ma}\n")
# Out:
# Etapa de entrenamiento desde 2025-02-24 hasta  2025-03-21
# Resultado obtenido entrenando desde 2025-02-24 hasta 2025-03-20
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7580645161290323
# risk reward: 0.5694704136459483
# profit factor: 2.4331917673963246
# trades: 62
# Resultado de sobre ajuste 1.7107049375823418
# Etapa de entrenamiento desde 2025-03-03 hasta  2025-03-28
# Resultado obtenido entrenando desde 2025-03-03 hasta 2025-03-27
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.746031746031746
# risk reward: 0.6113518030468577
# profit factor: 2.210271903323255
# trades: 63
# Resultado de sobre ajuste 1.1259272321641702
# Etapa de entrenamiento desde 2025-03-10 hasta  2025-04-04
# Resultado obtenido entrenando desde 2025-03-10 hasta 2025-04-03
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7222222222222222
# risk reward: 0.5711431990103286
# profit factor: 1.9799630899024727
# trades: 72
# Resultado de sobre ajuste 0.630983758636139
# Etapa de entrenamiento desde 2025-03-17 hasta  2025-04-11
# Resultado obtenido entrenando desde 2025-03-17 hasta 2025-04-10
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.78125
# risk reward: 0.6293546910755288
# profit factor: 2.420594965675111
# trades: 64
# Resultado de sobre ajuste 1.0167733885945476
# Etapa de entrenamiento desde 2025-03-24 hasta  2025-04-18
# Resultado obtenido entrenando desde 2025-03-24 hasta 2025-04-17
# Método: EMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8181818181818182
# risk reward: 0.65858181278742
# profit factor: 3.1915887850467275
# trades: 77
# Resultado de sobre ajuste 1.9685887562057385
# Etapa de entrenamiento desde 2025-03-31 hasta  2025-04-25
# Resultado obtenido entrenando desde 2025-03-31 hasta 2025-04-24
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8064516129032258
# risk reward: 0.5610714285714201
# profit factor: 3.117063492063445
# trades: 62
# Resultado de sobre ajuste 1.2193301934217626
# Etapa de entrenamiento desde 2025-04-07 hasta  2025-05-02
# Resultado obtenido entrenando desde 2025-04-07 hasta 2025-05-01
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.796875
# risk reward: 0.4382762914148399
# profit factor: 2.794011357769605
# trades: 64
# Resultado de sobre ajuste 1.2893363672149158
# Etapa de entrenamiento desde 2025-04-14 hasta  2025-05-09
# Resultado obtenido entrenando desde 2025-04-14 hasta 2025-05-08
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8541666666666666
# risk reward: 0.27392916539938134
# profit factor: 1.8718492968957725
# trades: 48
# Resultado de sobre ajuste 0.439088935682209
# Etapa de entrenamiento desde 2025-04-21 hasta  2025-05-16
# Resultado obtenido entrenando desde 2025-04-21 hasta 2025-05-15
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8095238095238095
# risk reward: 0.1477304429588462
# profit factor: 1.004567012120154
# trades: 42
# Resultado de sobre ajuste -0.6028204680976279
# Etapa de entrenamiento desde 2025-04-28 hasta  2025-05-23
# Resultado obtenido entrenando desde 2025-04-28 hasta 2025-05-22
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8142857142857143
# risk reward: 0.2947629102473812
# profit factor: 1.2924219910846715
# trades: 70
# Resultado de sobre ajuste -0.3599161758018555
# Etapa de entrenamiento desde 2025-05-05 hasta  2025-05-30
# Resultado obtenido entrenando desde 2025-05-05 hasta 2025-05-29
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7761194029850746
# risk reward: 0.2805225596321462
# profit factor: 0.9724782067247735
# trades: 67
# Resultado de sobre ajuste -0.8960666804119489
# Etapa de entrenamiento desde 2025-05-12 hasta  2025-06-06
# Resultado obtenido entrenando desde 2025-05-12 hasta 2025-06-05
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.855072463768116
# risk reward: 0.2451596521297492
# profit factor: 1.6071577195172448
# trades: 69
# Resultado de sobre ajuste 0.1168301026267651
# Etapa de entrenamiento desde 2025-05-19 hasta  2025-06-13
# Resultado obtenido entrenando desde 2025-05-19 hasta 2025-06-12
# Método: TEMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7604166666666666
# risk reward: 0.545580506008727
# profit factor: 1.731625084288568
# trades: 96
# Resultado de sobre ajuste -0.5178042777856919
# Etapa de entrenamiento desde 2025-05-26 hasta  2025-06-20
# Resultado obtenido entrenando desde 2025-05-26 hasta 2025-06-19
# Método: EMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8032786885245902
# risk reward: 0.24988548121709464
# profit factor: 1.1131262345125126
# trades: 61
# Resultado de sobre ajuste -1.0491028611430702
# Etapa de entrenamiento desde 2025-06-02 hasta  2025-06-27
# Resultado obtenido entrenando desde 2025-06-02 hasta 2025-06-26
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8846153846153846
# risk reward: 0.21044892188052539
# profit factor: 1.8151219512195316
# trades: 78
# Resultado de sobre ajuste 0.09393766772370092
# Etapa de entrenamiento desde 2025-06-09 hasta  2025-07-04
# Resultado obtenido entrenando desde 2025-06-09 hasta 2025-07-03
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8076923076923077
# risk reward: 0.747906766236689
# profit factor: 4.487440597420133
# trades: 52
# Resultado de sobre ajuste 1.6897723031594207
# Etapa de entrenamiento desde 2025-06-16 hasta  2025-07-11
# Resultado obtenido entrenando desde 2025-06-16 hasta 2025-07-10
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.9041095890410958
# risk reward: 0.334508348794077
# profit factor: 3.679591836734847
# trades: 73
# Resultado de sobre ajuste 1.525075529684031
# Etapa de entrenamiento desde 2025-06-23 hasta  2025-07-18
# Resultado obtenido entrenando desde 2025-06-23 hasta 2025-07-17
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8658536585365854
# risk reward: 0.29936326366067206
# profit factor: 2.1254791719907717
# trades: 82
# Resultado de sobre ajuste 0.8591804350885169
# Etapa de entrenamiento desde 2025-06-30 hasta  2025-07-25
# Resultado obtenido entrenando desde 2025-06-30 hasta 2025-07-24
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8470588235294118
# risk reward: 0.305957730071557
# profit factor: 1.8357463804293424
# trades: 85
# Resultado de sobre ajuste 0.518686822701531
# Etapa de entrenamiento desde 2025-07-07 hasta  2025-08-01
# Resultado obtenido entrenando desde 2025-07-07 hasta 2025-07-31
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8222222222222222
# risk reward: 0.2020438348796525
# profit factor: 0.9344527363183929
# trades: 90
# Resultado de sobre ajuste -0.8301429204429708
# Etapa de entrenamiento desde 2025-07-14 hasta  2025-08-08
# Resultado obtenido entrenando desde 2025-07-14 hasta 2025-08-07
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8024691358024691
# risk reward: 0.2866807221517095
# profit factor: 1.2422831293240744
# trades: 81
# Resultado de sobre ajuste -0.24824847232919808
# Etapa de entrenamiento desde 2025-07-21 hasta  2025-08-15
# Resultado obtenido entrenando desde 2025-07-21 hasta 2025-08-14
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8227848101265823
# risk reward: 0.32144937211522506
# profit factor: 1.4924435133921166
# trades: 79
# Resultado de sobre ajuste 0.18396748554600237
# Etapa de entrenamiento desde 2025-07-28 hasta  2025-08-22
# Resultado obtenido entrenando desde 2025-07-28 hasta 2025-08-21
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7741935483870968
# risk reward: 0.6521725157475173
# profit factor: 2.236020053991488
# trades: 31
# Resultado de sobre ajuste 0.6019782260475718
# Etapa de entrenamiento desde 2025-08-04 hasta  2025-08-29
# Resultado obtenido entrenando desde 2025-08-04 hasta 2025-08-28
# Método: EMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.76
# risk reward: 0.28919238752982895
# profit factor: 0.9157758938444585
# trades: 50
# Resultado de sobre ajuste -0.6105414433879898
# Etapa de entrenamiento desde 2025-08-11 hasta  2025-09-05
# Resultado obtenido entrenando desde 2025-08-11 hasta 2025-09-04
# Método: EMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7857142857142857
# risk reward: 0.27579543411828294
# profit factor: 1.1031817364731318
# trades: 56
# Resultado de sobre ajuste -1.1785767445960371
# Etapa de entrenamiento desde 2025-08-18 hasta  2025-09-12
# Resultado obtenido entrenando desde 2025-08-18 hasta 2025-09-11
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8208955223880597
# risk reward: 0.2191198786039423
# profit factor: 1.0955993930197117
# trades: 67
# Resultado de sobre ajuste -1.165923813504088
# Etapa de entrenamiento desde 2025-08-25 hasta  2025-09-19
# Resultado obtenido entrenando desde 2025-08-25 hasta 2025-09-18
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8166666666666667
# risk reward: 0.33312284451352053
# profit factor: 1.8136688201291673
# trades: 60
# Resultado de sobre ajuste 0.10772140420149852
# Etapa de entrenamiento desde 2025-09-01 hasta  2025-09-26
# Resultado obtenido entrenando desde 2025-09-01 hasta 2025-09-25
# Método: TEMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7184466019417476
# risk reward: 0.3931394676254113
# profit factor: 1.07749335571409
# trades: 103
# Resultado de sobre ajuste -0.591656156423428
# Etapa de entrenamiento desde 2025-09-08 hasta  2025-10-03
# Resultado obtenido entrenando desde 2025-09-08 hasta 2025-10-02
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8701298701298701
# risk reward: 0.17180038920845925
# profit factor: 1.4388282596208462
# trades: 77
# Resultado de sobre ajuste 0.05456413622918231
# Etapa de entrenamiento desde 2025-09-15 hasta  2025-10-10
# Resultado obtenido entrenando desde 2025-09-15 hasta 2025-10-09
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8205128205128205
# risk reward: 0.21618490732569862
# profit factor: 1.1529861724037258
# trades: 39
# Resultado de sobre ajuste -0.505851287907809
# Etapa de entrenamiento desde 2025-09-22 hasta  2025-10-17
# Resultado obtenido entrenando desde 2025-09-22 hasta 2025-10-16
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8205128205128205
# risk reward: 0.27910339199547424
# profit factor: 1.2759012205507394
# trades: 39
# Resultado de sobre ajuste 0.013481032344311378
# Etapa de entrenamiento desde 2025-09-29 hasta  2025-10-24
# Resultado obtenido entrenando desde 2025-09-29 hasta 2025-10-23
# Método: WMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8170731707317073
# risk reward: 0.21704843977530508
# profit factor: 1.0387318189246744
# trades: 82
# Resultado de sobre ajuste -0.17285587694277602
# Etapa de entrenamiento desde 2025-10-06 hasta  2025-10-31
# Resultado obtenido entrenando desde 2025-10-06 hasta 2025-10-30
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8157894736842105
# risk reward: 0.265521796565395
# profit factor: 1.371862615587874
# trades: 38
# Resultado de sobre ajuste -0.12510343507262298
# Etapa de entrenamiento desde 2025-10-13 hasta  2025-11-07
# Resultado obtenido entrenando desde 2025-10-13 hasta 2025-11-06
# Método: WMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8192771084337349
# risk reward: 0.2504082223890263
# profit factor: 1.3098276248041376
# trades: 83
# Resultado de sobre ajuste 0.4828073942870031
# Etapa de entrenamiento desde 2025-10-20 hasta  2025-11-14
# Resultado obtenido entrenando desde 2025-10-20 hasta 2025-11-13
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7959183673469388
# risk reward: 0.5273945497468754
# profit factor: 2.5710484300160177
# trades: 49
# Resultado de sobre ajuste 1.1930038869295654
# Etapa de entrenamiento desde 2025-10-27 hasta  2025-11-21
# Resultado obtenido entrenando desde 2025-10-27 hasta 2025-11-20
# Método: TRIMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8285714285714286
# risk reward: 0.3168804178402548
# profit factor: 1.5315886862278978
# trades: 70
# Resultado de sobre ajuste 0.6994474216394654
# Etapa de entrenamiento desde 2025-11-03 hasta  2025-11-28
# Resultado obtenido entrenando desde 2025-11-03 hasta 2025-11-27
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8461538461538461
# risk reward: 0.3039748130657248
# profit factor: 2.006233766233784
# trades: 39
# Resultado de sobre ajuste 1.3992965379346252
# Etapa de entrenamiento desde 2025-11-10 hasta  2025-12-05
# Resultado obtenido entrenando desde 2025-11-10 hasta 2025-12-04
# Método: SMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8208955223880597
# risk reward: 0.2711710001897792
# profit factor: 1.864300626304732
# trades: 67
# Resultado de sobre ajuste 1.4744700679150444
# Etapa de entrenamiento desde 2025-11-17 hasta  2025-12-12
# Resultado obtenido entrenando desde 2025-11-17 hasta 2025-12-11
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8571428571428571
# risk reward: 0.8646007816863066
# profit factor: 5.18760469011784
# trades: 42
# Resultado de sobre ajuste 1.607068107922316
# Etapa de entrenamiento desde 2025-11-24 hasta  2025-12-19
# Resultado obtenido entrenando desde 2025-11-24 hasta 2025-12-18
# Método: TRIMA, Datos optimizados [np.int64(16), np.int64(87)]
#
# hit ratio: 0.8070175438596491
# risk reward: 1.7367624223601692
# profit factor: 8.87678571428531
# trades: 57
# Resultado de sobre ajuste 3.8956434592413345
# Etapa de entrenamiento desde 2025-12-01 hasta  2025-12-26
# Resultado obtenido entrenando desde 2025-12-01 hasta 2025-12-24
# Método: T3, Datos optimizados [np.int64(15), np.int64(97)]
#
# hit ratio: 0.8928571428571429
# risk reward: 6.769756097560909
# profit factor: 56.41463414634091
# trades: 28
# Resultado de sobre ajuste 3.2111954408527246
# Etapa de entrenamiento desde 2025-12-08 hasta  2026-01-02
# Resultado obtenido entrenando desde 2025-12-08 hasta 2025-12-31
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8387096774193549
# risk reward: 0.552079138139352
# profit factor: 3.1897905759162564
# trades: 62
# Resultado de sobre ajuste 2.2945219489480424
# Etapa de entrenamiento desde 2025-12-15 hasta  2026-01-09
# Resultado obtenido entrenando desde 2025-12-15 hasta 2026-01-08
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7804878048780488
# risk reward: 0.45402644230770284
# profit factor: 1.8161057692308114
# trades: 41
# Resultado de sobre ajuste 1.2700727503512597
# Etapa de entrenamiento desde 2025-12-22 hasta  2026-01-16
# Resultado obtenido entrenando desde 2025-12-22 hasta 2026-01-15
# Método: SMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.6875
# risk reward: 0.4953436257784121
# profit factor: 1.1675956893348287
# trades: 48
# Resultado de sobre ajuste 0.39133897244291094
# Etapa de entrenamiento desde 2025-12-29 hasta  2026-01-23
# Resultado obtenido entrenando desde 2025-12-29 hasta 2026-01-22
# Método: TEMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7444444444444445
# risk reward: 0.3102415665367583
# profit factor: 1.0393092478981403
# trades: 90
# Resultado de sobre ajuste -0.6649822272807017
# Etapa de entrenamiento desde 2026-01-05 hasta  2026-01-30
# Resultado obtenido entrenando desde 2026-01-05 hasta 2026-01-29
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8108108108108109
# risk reward: 0.4669164882227108
# profit factor: 2.334582441113554
# trades: 37
# Resultado de sobre ajuste 1.069864094082897
# Etapa de entrenamiento desde 2026-01-12 hasta  2026-02-06
# Resultado obtenido entrenando desde 2026-01-12 hasta 2026-02-05
# Método: T3, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8108108108108109
# risk reward: 0.28850885088508393
# profit factor: 1.4425442544254197
# trades: 37
# Resultado de sobre ajuste 0.35305666394911245
# Etapa de entrenamiento desde 2026-01-19 hasta  2026-02-13
# Resultado obtenido entrenando desde 2026-01-19 hasta 2026-02-12
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.8787878787878788
# risk reward: 0.24089504884361598
# profit factor: 1.7464891041162158
# trades: 66
# Resultado de sobre ajuste 0.7804766308358214
# Etapa de entrenamiento desde 2026-01-26 hasta  2026-02-20
# Resultado obtenido entrenando desde 2026-01-26 hasta 2026-02-19
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7666666666666667
# risk reward: 0.31646679697818264
# profit factor: 1.2131227217497003
# trades: 60
# Resultado de sobre ajuste -0.014703827164810453
# Etapa de entrenamiento desde 2026-02-02 hasta  2026-02-27
# Resultado obtenido entrenando desde 2026-02-02 hasta 2026-02-19
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7555555555555555
# risk reward: 0.694575759052555
# profit factor: 2.951946975973359
# trades: 45
# Resultado de sobre ajuste 0.6188140284805969
# Etapa de entrenamiento desde 2026-02-09 hasta  2026-03-06
# Resultado obtenido entrenando desde 2026-02-09 hasta 2026-02-19
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(66)]
#
# hit ratio: 0.7407407407407407
# risk reward: 0.6484848484848005
# profit factor: 2.1616161616160015
# trades: 27
# Resultado de sobre ajuste 0.10350525377356144
