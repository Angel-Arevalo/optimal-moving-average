# %%
# lectura de los datos

import pandas as pd
import read_data

# Suponiendo que el activo tiene ese nombre
# solo es remplazar por el nombre que se tenga
# solo se acepta archivos .parquet y .csv
nombre_activo: str = "EURUSD_2019-2025.parquet"
data: pd.DataFrame = pd.read_parquet(f"Data/{nombre_activo}")

primer_lunes = data[data.index.dayofweek == 0].index[0]
ultimo_viernes = data[data.index.dayofweek == 4].index[-1]

data = data.loc[primer_lunes: ultimo_viernes]
data
# Out:
#                      Precio Spot
# time
# 2019-01-07 00:00:00     1.139460
# 2019-01-07 00:01:00     1.139530
# 2019-01-07 00:02:00     1.139530
# 2019-01-07 00:03:00     1.139490
# 2019-01-07 00:04:00     1.139520
# ...                          ...
# 2026-02-13 23:55:00     1.186825
# 2026-02-13 23:56:00     1.186825
# 2026-02-13 23:57:00     1.186825
# 2026-02-13 23:58:00     1.186825
# 2026-02-13 23:59:00     1.186825
#
# [2790713 rows x 1 columns]

# %%
import numpy as np
import pandas as pd

ma_week = []

with open("Data/Moving_average.txt", "r") as archivo:

    for line in archivo:
        start = pd.Timestamp(line[:10])
        fin = pd.Timestamp(line[11:21])

        lista = eval(line[22: -1], {"np": np})

        ma_week.append([start, fin, lista])

# %%
import read_data
import train_network
import pandas as pd
import numpy as np

X, y = train_network.get_features_cnn(data, ma_week, window_size=50)

if len(X) > 0:
    modelo, mae = train_network.train_cnn_velas_model(X, y)

    modelo.save("modelo_cnn_velas.keras")
else:
    print("No hay suficientes datos para entrenar.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774034575.465366   15445 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1774034575.546150   15445 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774034578.473328   15445 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1774034600.404753   15445 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Entrenando CNN Profunda con 14649 ejemplos...
# Epoch 1/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.4877 - val_loss: 0.4812 - learning_rate: 5.0000e-04
# Epoch 2/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 86ms/step - loss: 0.4780 - val_loss: 0.5123 - learning_rate: 5.0000e-04
# Epoch 3/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - loss: 0.4766 - val_loss: 0.4846 - learning_rate: 5.0000e-04
# Epoch 4/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - loss: 0.4739 - val_loss: 0.4807 - learning_rate: 5.0000e-04
# Epoch 5/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - loss: 0.4732 - val_loss: 0.5085 - learning_rate: 5.0000e-04
# Epoch 6/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - loss: 0.4716 - val_loss: 0.6468 - learning_rate: 5.0000e-04
# Epoch 7/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - loss: 0.4702 - val_loss: 0.8047 - learning_rate: 5.0000e-04
# Epoch 8/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 86ms/step - loss: 0.4697 - val_loss: 1.0131 - learning_rate: 5.0000e-04
# Epoch 9/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: 0.4703 - val_loss: 0.4879 - learning_rate: 5.0000e-04
# Epoch 10/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 0.4691 - val_loss: 1.5432 - learning_rate: 5.0000e-04
# Epoch 11/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: 0.4696 - val_loss: 0.7481 - learning_rate: 5.0000e-04
# Epoch 12/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: 0.4688 - val_loss: 1.0935 - learning_rate: 5.0000e-04
# Epoch 13/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 0.4690 - val_loss: 0.6463 - learning_rate: 5.0000e-04
# Epoch 14/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 0.4688 - val_loss: 0.4736 - learning_rate: 5.0000e-04
# Epoch 15/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 0.4671 - val_loss: 0.8006 - learning_rate: 5.0000e-04
# Epoch 16/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4676 - val_loss: 0.6300 - learning_rate: 5.0000e-04
# Epoch 17/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 91ms/step - loss: 0.4673 - val_loss: 0.5417 - learning_rate: 5.0000e-04
# Epoch 18/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4668 - val_loss: 0.4778 - learning_rate: 5.0000e-04
# Epoch 19/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 0.4669 - val_loss: 1.1542 - learning_rate: 5.0000e-04
# Epoch 20/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 0.4668 - val_loss: 0.4754 - learning_rate: 5.0000e-04
# Epoch 21/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 0.4663 - val_loss: 1.0518 - learning_rate: 5.0000e-04
# Epoch 22/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4659 - val_loss: 0.4975 - learning_rate: 5.0000e-04
# Epoch 23/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 91ms/step - loss: 0.4661 - val_loss: 1.5137 - learning_rate: 5.0000e-04
# Epoch 24/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - loss: 0.4651 - val_loss: 4.4042 - learning_rate: 5.0000e-04
# Epoch 25/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4638 - val_loss: 3.9640 - learning_rate: 2.5000e-04
# Epoch 26/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - loss: 0.4619 - val_loss: 1.7460 - learning_rate: 2.5000e-04
# Epoch 27/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - loss: 0.4616 - val_loss: 0.4850 - learning_rate: 2.5000e-04
# Epoch 28/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - loss: 0.4620 - val_loss: 0.4705 - learning_rate: 2.5000e-04
# Epoch 29/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 76ms/step - loss: 0.4600 - val_loss: 0.4954 - learning_rate: 2.5000e-04
# Epoch 30/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step - loss: 0.4572 - val_loss: 0.5412 - learning_rate: 2.5000e-04
# Epoch 31/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - loss: 0.4584 - val_loss: 0.5350 - learning_rate: 2.5000e-04
# Epoch 32/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - loss: 0.4572 - val_loss: 0.4937 - learning_rate: 2.5000e-04
# Epoch 33/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: 0.4547 - val_loss: 0.5380 - learning_rate: 2.5000e-04
# Epoch 34/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4517 - val_loss: 0.4746 - learning_rate: 2.5000e-04
# Epoch 35/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - loss: 0.4496 - val_loss: 0.4750 - learning_rate: 2.5000e-04
# Epoch 36/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4493 - val_loss: 0.4913 - learning_rate: 2.5000e-04
# Epoch 37/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 91ms/step - loss: 0.4460 - val_loss: 0.4799 - learning_rate: 2.5000e-04
# Epoch 38/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: 0.4416 - val_loss: 0.5387 - learning_rate: 2.5000e-04
# Epoch 39/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: 0.4341 - val_loss: 0.5713 - learning_rate: 1.2500e-04
# Epoch 40/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: 0.4285 - val_loss: 1.0254 - learning_rate: 1.2500e-04
# Epoch 41/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 95ms/step - loss: 0.4249 - val_loss: 0.4877 - learning_rate: 1.2500e-04
# Epoch 42/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step - loss: 0.4212 - val_loss: 0.5562 - learning_rate: 1.2500e-04
# Epoch 43/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: 0.4197 - val_loss: 1.8163 - learning_rate: 1.2500e-04
# Epoch 44/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - loss: 0.4146 - val_loss: 0.6739 - learning_rate: 1.2500e-04
# Epoch 45/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - loss: 0.4112 - val_loss: 0.5533 - learning_rate: 1.2500e-04
# Epoch 46/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - loss: 0.4090 - val_loss: 0.6214 - learning_rate: 1.2500e-04
# Epoch 47/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - loss: 0.4052 - val_loss: 6.9157 - learning_rate: 1.2500e-04
# Epoch 48/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - loss: 0.4032 - val_loss: 0.7014 - learning_rate: 1.2500e-04
# Epoch 49/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 0.3930 - val_loss: 0.9061 - learning_rate: 6.2500e-05
# Epoch 50/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - loss: 0.3886 - val_loss: 0.5038 - learning_rate: 6.2500e-05
# Epoch 51/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - loss: 0.3861 - val_loss: 2.1443 - learning_rate: 6.2500e-05
# Epoch 52/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 20s 77ms/step - loss: 0.3859 - val_loss: 4.8817 - learning_rate: 6.2500e-05
# Epoch 53/300
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - loss: 0.3826 - val_loss: 9.3940 - learning_rate: 6.2500e-05
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# MAE Alcanzado: 4.9683 velas.

# %%
from using_ia_model import procesar_estrategia_con_cnn

procesar_estrategia_con_cnn(data, ma_week)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from using_ia_model import procesar_estrategia_con_cnn
# ----> 3 procesar_estrategia_con_cnn(data, ma_week)
#
# File ~/Documents/optimal-moving-average/using_ia_model.py:56, in procesar_estrategia_con_cnn(data, ma_week, window_size)
#      53 time_col = inicio_w - pd.Timedelta(weeks=2)
#      54 data_week = data.loc[time_col: fin_w]
# ---> 56 prices = read_data.ohlc_form(data_week, f"{candle}min")["close"]
#      57 ma = SIMPLE_METHODS[metodo](prices, params)
#      59 base_signals_full = get_vector_buys(ma, prices)
#
# NameError: name 'read_data' is not defined

# %%
import pandas as pd
import find_best
import keys
from use_tecnics import simple_methods

keys.methods = simple_methods
keys.candles = 20
keys.calls = 20

dias_comp_sem = pd.Timedelta(days=4)
next_lun = pd.Timedelta(days=3)
ventana_ent = pd.Timedelta(weeks=3) + dias_comp_sem

primer_lunes = data[data.index.dayofweek == 0].index[0]
ultimo_viernes = data[data.index.dayofweek == 4].index[-1]

inicio_actual = primer_lunes

with open("Data/Moving_average.txt", "w") as archivo:
    archivo.write("") 

while True:
    train_time_init = inicio_actual
    train_time_fin = inicio_actual + ventana_ent

    test_time_init = train_time_fin + next_lun
    test_time_fin = test_time_init + dias_comp_sem

    if train_time_fin >= ultimo_viernes:
        break

    print(f"Optimizando ventana: {train_time_init.date()} al {train_time_fin.date()}")

    data_w = data.loc[train_time_init : train_time_fin]
    
    if len(data_w) < 100:
        inicio_actual += (dias_comp_sem + next_lun)
        continue

    best_ma = find_best.opti_main(data_w)

    with open("Data/Moving_average.txt", "a") as archivo:
        archivo.write(f"{test_time_init.date()} {test_time_fin.date()}, {best_ma}\n")

    inicio_actual += (dias_comp_sem + next_lun)
# Out:
# Optimizando ventana: 2019-01-07 al 2019-02-01
# Resultado obtenido entrenando desde 2019-01-07 hasta 2019-02-01
# Método: T3, Datos optimizados [np.int64(19), np.int64(83)]
#
# hit ratio: 0.8913043478260869
# risk reward: 0.3026464982750679
# profit factor: 2.4817012858555567
# trades: 46
# Resultado de sobre ajuste 0.5608402647361452
# Optimizando ventana: 2019-01-14 al 2019-02-08
# Resultado obtenido entrenando desde 2019-01-14 hasta 2019-02-08
# Método: KAMA, Datos optimizados [np.int64(7), np.int64(23)]
#
# hit ratio: 0.8190045248868778
# risk reward: 0.2786792436287588
# profit factor: 1.293357515302701
# trades: 221
# Resultado de sobre ajuste 0.35219298101033336
# Optimizando ventana: 2019-01-21 al 2019-02-15
# Resultado obtenido entrenando desde 2019-01-21 hasta 2019-02-15
# Método: TEMA, Datos optimizados [np.int64(12), np.int64(33)]
#
# hit ratio: 0.7391304347826086
# risk reward: 0.4951797385621071
# profit factor: 1.4030092592593038
# trades: 207
# Resultado de sobre ajuste -0.2458811253005276
# Optimizando ventana: 2019-01-28 al 2019-02-22
# Resultado obtenido entrenando desde 2019-01-28 hasta 2019-02-22
# Método: WMA, Datos optimizados [np.int64(18), np.int64(84)]
#
# hit ratio: 0.8095238095238095
# risk reward: 0.3530573049265266
# profit factor: 1.636902050113896
# trades: 63
# Resultado de sobre ajuste 0.16465054351090744
# Optimizando ventana: 2019-02-04 al 2019-03-01
# Resultado obtenido entrenando desde 2019-02-04 hasta 2019-03-01
# Método: KAMA, Datos optimizados [np.int64(19), np.int64(17)]
#
# hit ratio: 0.7272727272727273
# risk reward: 0.5797286184210719
# profit factor: 1.6131578947368956
# trades: 88
# Resultado de sobre ajuste 0.46541532286438514
# Optimizando ventana: 2019-02-11 al 2019-03-08
# Resultado obtenido entrenando desde 2019-02-11 hasta 2019-03-08
# Método: EMA, Datos optimizados [np.int64(10), np.int64(96)]
#
# hit ratio: 0.8558558558558559
# risk reward: 0.47619047619046057
# profit factor: 3.2312925170066964
# trades: 111
# Resultado de sobre ajuste -0.4685646526779177
# Optimizando ventana: 2019-02-18 al 2019-03-15
# Resultado obtenido entrenando desde 2019-02-18 hasta 2019-03-15
# Método: MIDPOINT, Datos optimizados [np.int64(11), np.int64(86)]
#
# hit ratio: 0.8202247191011236
# risk reward: 0.28446741466372755
# profit factor: 1.7305101058710093
# trades: 89
# Resultado de sobre ajuste 0.12972893079325482
# Optimizando ventana: 2019-02-25 al 2019-03-22
# Resultado obtenido entrenando desde 2019-02-25 hasta 2019-03-22
# Método: SMA, Datos optimizados [np.int64(13), np.int64(96)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.2320707070706979
# profit factor: 1.595486111111048
# trades: 66
# Resultado de sobre ajuste 0.16657286503393595
# Optimizando ventana: 2019-03-04 al 2019-03-29
# Resultado obtenido entrenando desde 2019-03-04 hasta 2019-03-29
# Método: T3, Datos optimizados [np.int64(13), np.int64(90)]
#
# hit ratio: 0.8863636363636364
# risk reward: 0.17997059238222163
# profit factor: 1.4037706205813287
# trades: 44
# Resultado de sobre ajuste -0.26769480115862815
# Optimizando ventana: 2019-03-11 al 2019-04-05
# Resultado obtenido entrenando desde 2019-03-11 hasta 2019-04-05
# Método: MIDPOINT, Datos optimizados [np.int64(20), np.int64(62)]
#
# hit ratio: 0.7291666666666666
# risk reward: 0.4937908000607247
# profit factor: 1.9202975557917072
# trades: 48
# Resultado de sobre ajuste 0.5498530116104364
# Optimizando ventana: 2019-03-18 al 2019-04-12
# Resultado obtenido entrenando desde 2019-03-18 hasta 2019-04-12
# Método: EMA, Datos optimizados [np.int64(14), np.int64(21)]
#
# hit ratio: 0.8248175182481752
# risk reward: 0.265271779555792
# profit factor: 1.3032917865132392
# trades: 137
# Resultado de sobre ajuste 0.14591194253439657
# Optimizando ventana: 2019-03-25 al 2019-04-19
# Resultado obtenido entrenando desde 2019-03-25 hasta 2019-04-19
# Método: T3, Datos optimizados [np.int64(8), np.int64(62)]
#
# hit ratio: 0.8314606741573034
# risk reward: 0.3676475817923042
# profit factor: 2.092763157894655
# trades: 89
# Resultado de sobre ajuste 0.645067065522982
# Optimizando ventana: 2019-04-01 al 2019-04-26
# Resultado obtenido entrenando desde 2019-04-01 hasta 2019-04-26
# Método: TRIMA, Datos optimizados [np.int64(17), np.int64(97)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.2379547689282321
# profit factor: 1.784660766961741
# trades: 36
# Resultado de sobre ajuste -0.556454133716381
# Optimizando ventana: 2019-04-08 al 2019-05-03
# Resultado obtenido entrenando desde 2019-04-08 hasta 2019-05-03
# Método: TEMA, Datos optimizados [np.int64(7), np.int64(93)]
#
# hit ratio: 0.7755102040816326
# risk reward: 0.32763510443271987
# profit factor: 1.2450133968443355
# trades: 196
# Resultado de sobre ajuste 0.355056341379185
# Optimizando ventana: 2019-04-15 al 2019-05-10
# Resultado obtenido entrenando desde 2019-04-15 hasta 2019-05-10
# Método: TRIMA, Datos optimizados [np.int64(9), np.int64(93)]
#
# hit ratio: 0.8155339805825242
# risk reward: 0.2956160431122927
# profit factor: 1.4606910365548584
# trades: 103
# Resultado de sobre ajuste 0.38558810636368057
# Optimizando ventana: 2019-04-22 al 2019-05-17
# Resultado obtenido entrenando desde 2019-04-22 hasta 2019-05-17
# Método: TEMA, Datos optimizados [np.int64(15), np.int64(100)]
#
# hit ratio: 0.8452380952380952
# risk reward: 0.5731591622272341
# profit factor: 3.699481865284874
# trades: 84
# Resultado de sobre ajuste 0.7695064995718048
# Optimizando ventana: 2019-04-29 al 2019-05-24
# Resultado obtenido entrenando desde 2019-04-29 hasta 2019-05-24
# Método: KAMA, Datos optimizados [np.int64(17), np.int64(40)]
#
# hit ratio: 0.8787878787878788
# risk reward: 0.3406113537118061
# profit factor: 2.4694323144105943
# trades: 66
# Resultado de sobre ajuste 1.4862538029119519
# Optimizando ventana: 2019-05-06 al 2019-05-31
# Resultado obtenido entrenando desde 2019-05-06 hasta 2019-05-31
# Método: TRIMA, Datos optimizados [np.int64(13), np.int64(93)]
#
# hit ratio: 0.8607594936708861
# risk reward: 0.25606074467113266
# profit factor: 1.934681181959669
# trades: 79
# Resultado de sobre ajuste 0.7571566627304953
# Optimizando ventana: 2019-05-13 al 2019-06-07
# Resultado obtenido entrenando desde 2019-05-13 hasta 2019-06-07
# Método: T3, Datos optimizados [np.int64(18), np.int64(18)]
#
# hit ratio: 0.7222222222222222
# risk reward: 0.6737901052707174
# profit factor: 1.8248482017748595
# trades: 90
# Resultado de sobre ajuste 1.3115135568131537
# Optimizando ventana: 2019-05-20 al 2019-06-14
# Resultado obtenido entrenando desde 2019-05-20 hasta 2019-06-14
# Método: DEMA, Datos optimizados [np.int64(19), np.int64(53)]
#
# hit ratio: 0.782608695652174
# risk reward: 0.47746598639452925
# profit factor: 1.8093447905476896
# trades: 92
# Resultado de sobre ajuste 1.5923173362306067
# Optimizando ventana: 2019-05-27 al 2019-06-21
# Resultado obtenido entrenando desde 2019-05-27 hasta 2019-06-21
# Método: DEMA, Datos optimizados [np.int64(9), np.int64(34)]
#
# hit ratio: 0.78125
# risk reward: 0.45856347112281903
# profit factor: 1.7074171797126243
# trades: 224
# Resultado de sobre ajuste 1.6205343284228222
# Optimizando ventana: 2019-06-03 al 2019-06-28
# Resultado obtenido entrenando desde 2019-06-03 hasta 2019-06-28
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(106)]
#
# hit ratio: 0.8103448275862069
# risk reward: 0.39712680353001517
# profit factor: 2.0738844184345235
# trades: 58
# Resultado de sobre ajuste 0.7391042490073585
# Optimizando ventana: 2019-06-10 al 2019-07-05
# Resultado obtenido entrenando desde 2019-06-10 hasta 2019-07-05
# Método: TRIMA, Datos optimizados [np.int64(12), np.int64(73)]
#
# hit ratio: 0.8279569892473119
# risk reward: 0.23296208435528132
# profit factor: 1.4948400412797218
# trades: 93
# Resultado de sobre ajuste 0.23677653874815394
# Optimizando ventana: 2019-06-17 al 2019-07-12
# Resultado obtenido entrenando desde 2019-06-17 hasta 2019-07-12
# Método: SMA, Datos optimizados [np.int64(10), np.int64(22)]
#
# hit ratio: 0.7543859649122807
# risk reward: 0.5647616723458122
# profit factor: 1.9172172561213097
# trades: 171
# Resultado de sobre ajuste 1.0175841086478719
# Optimizando ventana: 2019-06-24 al 2019-07-19
# Resultado obtenido entrenando desde 2019-06-24 hasta 2019-07-19
# Método: KAMA, Datos optimizados [np.int64(5), np.int64(93)]
#
# hit ratio: 0.8512820512820513
# risk reward: 0.2337761805166989
# profit factor: 1.385958784491858
# trades: 195
# Resultado de sobre ajuste 0.5996666023837214
# Optimizando ventana: 2019-07-01 al 2019-07-26
# Resultado obtenido entrenando desde 2019-07-01 hasta 2019-07-26
# Método: TEMA, Datos optimizados [np.int64(10), np.int64(48)]
#
# hit ratio: 0.7451923076923077
# risk reward: 0.42589349553899425
# profit factor: 1.320269836170882
# trades: 208
# Resultado de sobre ajuste -0.08647870971125951
# Optimizando ventana: 2019-07-08 al 2019-08-02
# Resultado obtenido entrenando desde 2019-07-08 hasta 2019-08-02
# Método: TRIMA, Datos optimizados [np.int64(8), np.int64(32)]
#
# hit ratio: 0.7752808988764045
# risk reward: 0.3530719302925359
# profit factor: 1.3534423994547211
# trades: 178
# Resultado de sobre ajuste 0.5559949804814306
# Optimizando ventana: 2019-07-15 al 2019-08-09
# Resultado obtenido entrenando desde 2019-07-15 hasta 2019-08-09
# Método: MIDPOINT, Datos optimizados [np.int64(5), np.int64(60)]
#
# hit ratio: 0.8325123152709359
# risk reward: 0.24903774343655538
# profit factor: 1.357657375508963
# trades: 203
# Resultado de sobre ajuste 0.6260405901310826
# Optimizando ventana: 2019-07-22 al 2019-08-16
# Resultado obtenido entrenando desde 2019-07-22 hasta 2019-08-16
# Método: KAMA, Datos optimizados [np.int64(19), np.int64(83)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.24204256670902596
# profit factor: 1.383100381194434
# trades: 48
# Resultado de sobre ajuste -0.1095458190715662
# Optimizando ventana: 2019-07-29 al 2019-08-23
# Resultado obtenido entrenando desde 2019-07-29 hasta 2019-08-23
# Método: TEMA, Datos optimizados [np.int64(18), np.int64(101)]
#
# hit ratio: 0.7941176470588235
# risk reward: 0.42503159953257835
# profit factor: 1.639407598197088
# trades: 68
# Resultado de sobre ajuste -0.019663784255061087
# Optimizando ventana: 2019-08-05 al 2019-08-30
# Resultado obtenido entrenando desde 2019-08-05 hasta 2019-08-30
# Método: MIDPOINT, Datos optimizados [np.int64(10), np.int64(110)]
#
# hit ratio: 0.7564102564102564
# risk reward: 0.3991056456121001
# profit factor: 1.3851313583008178
# trades: 78
# Resultado de sobre ajuste 0.6500782738034292
# Optimizando ventana: 2019-08-12 al 2019-09-06
# Resultado obtenido entrenando desde 2019-08-12 hasta 2019-09-06
# Método: DEMA, Datos optimizados [np.int64(10), np.int64(100)]
#
# hit ratio: 0.7819548872180451
# risk reward: 0.3783687703142081
# profit factor: 1.405369718309916
# trades: 133
# Resultado de sobre ajuste 1.019210650309521
# Optimizando ventana: 2019-08-19 al 2019-09-13
# Resultado obtenido entrenando desde 2019-08-19 hasta 2019-09-13
# Método: T3, Datos optimizados [np.int64(8), np.int64(32)]
#
# hit ratio: 0.8109756097560976
# risk reward: 0.30794424556325883
# profit factor: 1.4627351664254793
# trades: 164
# Resultado de sobre ajuste 0.2533753754563396
# Optimizando ventana: 2019-08-26 al 2019-09-20
# Resultado obtenido entrenando desde 2019-08-26 hasta 2019-09-20
# Método: TRIMA, Datos optimizados [np.int64(1), np.int64(98)]
#
# hit ratio: 0.8545454545454545
# risk reward: 0.19468975262920551
# profit factor: 1.2437461866991963
# trades: 770
# Resultado de sobre ajuste -0.15442531085081343
# Optimizando ventana: 2019-09-02 al 2019-09-27
# Resultado obtenido entrenando desde 2019-09-02 hasta 2019-09-27
# Método: T3, Datos optimizados [np.int64(20), np.int64(33)]
#
# hit ratio: 0.7727272727272727
# risk reward: 0.2436261710950548
# profit factor: 0.9203655352479847
# trades: 44
# Resultado de sobre ajuste -0.9227238640297029
# Optimizando ventana: 2019-09-09 al 2019-10-04
# Resultado obtenido entrenando desde 2019-09-09 hasta 2019-10-04
# Método: SMA, Datos optimizados [np.int64(13), np.int64(76)]
#
# hit ratio: 0.7868852459016393
# risk reward: 0.23171688637789592
# profit factor: 1.1122410546139005
# trades: 61
# Resultado de sobre ajuste -1.2175269958081996
# Optimizando ventana: 2019-09-16 al 2019-10-11
# Resultado obtenido entrenando desde 2019-09-16 hasta 2019-10-11
# Método: TEMA, Datos optimizados [np.int64(13), np.int64(16)]
#
# hit ratio: 0.6908396946564885
# risk reward: 0.5571919473424795
# profit factor: 1.2929710572947282
# trades: 262
# Resultado de sobre ajuste 0.08373715347470825
# Optimizando ventana: 2019-09-23 al 2019-10-18
# Resultado obtenido entrenando desde 2019-09-23 hasta 2019-10-18
# Método: T3, Datos optimizados [np.int64(19), np.int64(79)]
#
# hit ratio: 0.9354838709677419
# risk reward: 0.28282828282829764
# profit factor: 4.101010101010315
# trades: 31
# Resultado de sobre ajuste 0.9471054783707179
# Optimizando ventana: 2019-09-30 al 2019-10-25
# Resultado obtenido entrenando desde 2019-09-30 hasta 2019-10-25
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(98)]
#
# hit ratio: 0.8923076923076924
# risk reward: 2.568345323740235
# profit factor: 21.280575539561948
# trades: 65
# Resultado de sobre ajuste 0.6371787676676322
# Optimizando ventana: 2019-10-07 al 2019-11-01
# Resultado obtenido entrenando desde 2019-10-07 hasta 2019-11-01
# Método: T3, Datos optimizados [np.int64(7), np.int64(74)]
#
# hit ratio: 0.8877551020408163
# risk reward: 0.36968629699401606
# profit factor: 3.5736342042754887
# trades: 98
# Resultado de sobre ajuste 2.0225940947127183
# Optimizando ventana: 2019-10-14 al 2019-11-08
# Resultado obtenido entrenando desde 2019-10-14 hasta 2019-11-08
# Método: SMA, Datos optimizados [np.int64(18), np.int64(22)]
#
# hit ratio: 0.83
# risk reward: 0.29373603009321536
# profit factor: 1.6253393665157916
# trades: 100
# Resultado de sobre ajuste 0.6741180784691353
# Optimizando ventana: 2019-10-21 al 2019-11-15
# Resultado obtenido entrenando desde 2019-10-21 hasta 2019-11-15
# Método: TRIMA, Datos optimizados [np.int64(16), np.int64(26)]
#
# hit ratio: 0.8235294117647058
# risk reward: 0.24363521940614033
# profit factor: 1.136964357228655
# trades: 102
# Resultado de sobre ajuste -0.6780767889007013
# Optimizando ventana: 2019-10-28 al 2019-11-22
# Resultado obtenido entrenando desde 2019-10-28 hasta 2019-11-22
# Método: MIDPOINT, Datos optimizados [np.int64(10), np.int64(29)]
#
# hit ratio: 0.7806451612903226
# risk reward: 0.40462794884229103
# profit factor: 1.5793542519328136
# trades: 155
# Resultado de sobre ajuste -0.18901295632069615
# Optimizando ventana: 2019-11-04 al 2019-11-29
# Resultado obtenido entrenando desde 2019-11-04 hasta 2019-11-29
# Método: DEMA, Datos optimizados [np.int64(18), np.int64(75)]
#
# hit ratio: 0.7439024390243902
# risk reward: 0.3516730294183827
# profit factor: 1.1917808219178523
# trades: 82
# Resultado de sobre ajuste 0.4398498640875761
# Optimizando ventana: 2019-11-11 al 2019-12-06
# Resultado obtenido entrenando desde 2019-11-11 hasta 2019-12-06
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(22)]
#
# hit ratio: 0.8350515463917526
# risk reward: 0.3926435026091526
# profit factor: 2.1202749140894244
# trades: 97
# Resultado de sobre ajuste 0.7738903877256456
# Optimizando ventana: 2019-11-18 al 2019-12-13
# Resultado obtenido entrenando desde 2019-11-18 hasta 2019-12-13
# Método: EMA, Datos optimizados [np.int64(6), np.int64(21)]
#
# hit ratio: 0.7877906976744186
# risk reward: 0.372025496846658
# profit factor: 1.575295463210067
# trades: 344
# Resultado de sobre ajuste 1.0687899487543224
# Optimizando ventana: 2019-11-25 al 2019-12-20
# Resultado obtenido entrenando desde 2019-11-25 hasta 2019-12-20
# Método: MIDPOINT, Datos optimizados [np.int64(2), np.int64(13)]
#
# hit ratio: 0.7172284644194756
# risk reward: 0.47780427272624515
# profit factor: 1.355548418178903
# trades: 1068
# Resultado de sobre ajuste 0.5838143200693782
# Optimizando ventana: 2019-12-02 al 2019-12-27
# Resultado obtenido entrenando desde 2019-12-02 hasta 2019-12-27
# Método: WMA, Datos optimizados [np.int64(2), np.int64(9)]
#
# hit ratio: 0.7215269086357947
# risk reward: 0.4614718124465251
# profit factor: 1.3892349862946303
# trades: 1598
# Resultado de sobre ajuste -0.6743716452433459
# Optimizando ventana: 2019-12-09 al 2020-01-03
# Resultado obtenido entrenando desde 2019-12-09 hasta 2020-01-03
# Método: KAMA, Datos optimizados [np.int64(12), np.int64(82)]
#
# hit ratio: 0.8375
# risk reward: 0.2700277821208327
# profit factor: 1.5076551168413164
# trades: 80
# Resultado de sobre ajuste 0.3591462292811346
# Optimizando ventana: 2019-12-16 al 2020-01-10
# Resultado obtenido entrenando desde 2019-12-16 hasta 2020-01-10
# Método: MIDPOINT, Datos optimizados [np.int64(3), np.int64(9)]
#
# hit ratio: 0.6753069577080492
# risk reward: 0.44361268448881364
# profit factor: 1.030930886488088
# trades: 733
# Resultado de sobre ajuste -0.3106148382494808
# Optimizando ventana: 2019-12-23 al 2020-01-17
# Resultado obtenido entrenando desde 2019-12-23 hasta 2020-01-17
# Método: KAMA, Datos optimizados [np.int64(5), np.int64(99)]
#
# hit ratio: 0.8743169398907104
# risk reward: 0.1882970244420933
# profit factor: 1.5063761955367463
# trades: 183
# Resultado de sobre ajuste 0.04222504059144299
# Optimizando ventana: 2019-12-30 al 2020-01-24
# Resultado obtenido entrenando desde 2019-12-30 hasta 2020-01-24
# Método: WMA, Datos optimizados [np.int64(1), np.int64(73)]
#
# hit ratio: 0.8031037827352085
# risk reward: 0.2226312184586202
# profit factor: 1.0414612931284606
# trades: 1031
# Resultado de sobre ajuste -0.06586982255272723
# Optimizando ventana: 2020-01-06 al 2020-01-31
# Resultado obtenido entrenando desde 2020-01-06 hasta 2020-01-31
# Método: T3, Datos optimizados [np.int64(7), np.int64(103)]
#
# hit ratio: 0.8469387755102041
# risk reward: 0.24612382267573274
# profit factor: 1.4591626630061298
# trades: 98
# Resultado de sobre ajuste 0.2607679724889201
# Optimizando ventana: 2020-01-13 al 2020-02-07
# Resultado obtenido entrenando desde 2020-01-13 hasta 2020-02-07
# Método: WMA, Datos optimizados [np.int64(1), np.int64(106)]
#
# hit ratio: 0.8162650602409639
# risk reward: 0.23591682419659368
# profit factor: 1.2294896030245557
# trades: 996
# Resultado de sobre ajuste 0.12541225133613326
# Optimizando ventana: 2020-01-20 al 2020-02-14
# Resultado obtenido entrenando desde 2020-01-20 hasta 2020-02-14
# Método: T3, Datos optimizados [np.int64(1), np.int64(109)]
#
# hit ratio: 0.834597875569044
# risk reward: 0.18152466367713235
# profit factor: 1.1345291479820772
# trades: 659
# Resultado de sobre ajuste -0.07811296429278006
# Optimizando ventana: 2020-01-27 al 2020-02-21
# Resultado obtenido entrenando desde 2020-01-27 hasta 2020-02-21
# Método: DEMA, Datos optimizados [np.int64(1), np.int64(42)]
#
# hit ratio: 0.7291311754684838
# risk reward: 0.3201818888101595
# profit factor: 0.9978484107578758
# trades: 1761
# Resultado de sobre ajuste -0.005912820223489675
# Optimizando ventana: 2020-02-03 al 2020-02-28
# Resultado obtenido entrenando desde 2020-02-03 hasta 2020-02-28
# Método: DEMA, Datos optimizados [np.int64(10), np.int64(22)]
#
# hit ratio: 0.7091633466135459
# risk reward: 0.4726614213211333
# profit factor: 1.2372607793406136
# trades: 251
# Resultado de sobre ajuste 0.6933473270313022
# Optimizando ventana: 2020-02-10 al 2020-03-06
# Resultado obtenido entrenando desde 2020-02-10 hasta 2020-03-06
# Método: T3, Datos optimizados [np.int64(16), np.int64(50)]
#
# hit ratio: 0.8541666666666666
# risk reward: 0.3976819001118012
# profit factor: 2.717492984097308
# trades: 48
# Resultado de sobre ajuste 1.072626366488306
# Optimizando ventana: 2020-02-17 al 2020-03-13
# Resultado obtenido entrenando desde 2020-02-17 hasta 2020-03-13
# Método: SMA, Datos optimizados [np.int64(10), np.int64(64)]
#
# hit ratio: 0.8163265306122449
# risk reward: 0.34822354771784675
# profit factor: 1.8571922544951824
# trades: 98
# Resultado de sobre ajuste 0.9757897603469344
# Optimizando ventana: 2020-02-24 al 2020-03-20
# Resultado obtenido entrenando desde 2020-02-24 hasta 2020-03-20
# Método: SMA, Datos optimizados [np.int64(10), np.int64(68)]
#
# hit ratio: 0.8426966292134831
# risk reward: 0.21719311102968525
# profit factor: 1.3574569439355328
# trades: 89
# Resultado de sobre ajuste -0.44683786839924977
# Optimizando ventana: 2020-03-02 al 2020-03-27
# Resultado obtenido entrenando desde 2020-03-02 hasta 2020-03-27
# Método: EMA, Datos optimizados [np.int64(15), np.int64(28)]
#
# hit ratio: 0.8108108108108109
# risk reward: 0.2829505227628266
# profit factor: 1.2732773524327197
# trades: 111
# Resultado de sobre ajuste -0.16856274478180683
# Optimizando ventana: 2020-03-09 al 2020-04-03
# Resultado obtenido entrenando desde 2020-03-09 hasta 2020-04-03
# Método: EMA, Datos optimizados [np.int64(7), np.int64(75)]
#
# hit ratio: 0.8074074074074075
# risk reward: 0.26992629821745784
# profit factor: 1.1316140963731887
# trades: 135
# Resultado de sobre ajuste 0.3468747607250675
# Optimizando ventana: 2020-03-16 al 2020-04-10
# Resultado obtenido entrenando desde 2020-03-16 hasta 2020-04-10
# Método: TEMA, Datos optimizados [np.int64(20), np.int64(63)]
#
# hit ratio: 0.7951807228915663
# risk reward: 0.3478977163187694
# profit factor: 1.5307499518025856
# trades: 83
# Resultado de sobre ajuste -0.05240371788587043
# Optimizando ventana: 2020-03-23 al 2020-04-17
# Resultado obtenido entrenando desde 2020-03-23 hasta 2020-04-17
# Método: KAMA, Datos optimizados [np.int64(15), np.int64(8)]
#
# hit ratio: 0.7410071942446043
# risk reward: 0.48600458789999357
# profit factor: 1.3905131264916482
# trades: 139
# Resultado de sobre ajuste 0.7704611070156152
# Optimizando ventana: 2020-03-30 al 2020-04-24
# Resultado obtenido entrenando desde 2020-03-30 hasta 2020-04-24
# Método: TEMA, Datos optimizados [np.int64(15), np.int64(103)]
#
# hit ratio: 0.7872340425531915
# risk reward: 0.3357588357588246
# profit factor: 1.242307692307651
# trades: 94
# Resultado de sobre ajuste -0.2972849416856869
# Optimizando ventana: 2020-04-06 al 2020-05-01
# Resultado obtenido entrenando desde 2020-04-06 hasta 2020-05-01
# Método: EMA, Datos optimizados [np.int64(13), np.int64(100)]
#
# hit ratio: 0.8208955223880597
# risk reward: 0.43049095607234394
# profit factor: 2.1524547803617193
# trades: 67
# Resultado de sobre ajuste 0.3837213097480296
# Optimizando ventana: 2020-04-13 al 2020-05-08
# Resultado obtenido entrenando desde 2020-04-13 hasta 2020-05-08
# Método: T3, Datos optimizados [np.int64(10), np.int64(96)]
#
# hit ratio: 0.8412698412698413
# risk reward: 0.2900684221439094
# profit factor: 1.7081807081807998
# trades: 63
# Resultado de sobre ajuste -0.19724684206622395
# Optimizando ventana: 2020-04-20 al 2020-05-15
# Resultado obtenido entrenando desde 2020-04-20 hasta 2020-05-15
# Método: MIDPOINT, Datos optimizados [np.int64(16), np.int64(43)]
#
# hit ratio: 0.7746478873239436
# risk reward: 0.396703964537224
# profit factor: 1.4545812033031544
# trades: 71
# Resultado de sobre ajuste -0.058790915204350584
# Optimizando ventana: 2020-04-27 al 2020-05-22
# Resultado obtenido entrenando desde 2020-04-27 hasta 2020-05-22
# Método: KAMA, Datos optimizados [np.int64(12), np.int64(105)]
#
# hit ratio: 0.8977272727272727
# risk reward: 0.24061808509844965
# profit factor: 2.3761035903471903
# trades: 88
# Resultado de sobre ajuste 0.7748070749428072
# Optimizando ventana: 2020-05-04 al 2020-05-29
# Resultado obtenido entrenando desde 2020-05-04 hasta 2020-05-29
# Método: EMA, Datos optimizados [np.int64(16), np.int64(81)]
#
# hit ratio: 0.84
# risk reward: 0.35600206079339924
# profit factor: 2.1360123647603952
# trades: 50
# Resultado de sobre ajuste 0.9308250609216775
# Optimizando ventana: 2020-05-11 al 2020-06-05
# Resultado obtenido entrenando desde 2020-05-11 hasta 2020-06-05
# Método: T3, Datos optimizados [np.int64(20), np.int64(26)]
#
# hit ratio: 0.8392857142857143
# risk reward: 0.5514012256420858
# profit factor: 3.7022653721682905
# trades: 56
# Resultado de sobre ajuste 0.8097236055332697
# Optimizando ventana: 2020-05-18 al 2020-06-12
# Resultado obtenido entrenando desde 2020-05-18 hasta 2020-06-12
# Método: T3, Datos optimizados [np.int64(14), np.int64(98)]
#
# hit ratio: 0.9565217391304348
# risk reward: 0.5607575757576373
# profit factor: 24.673333333336043
# trades: 46
# Resultado de sobre ajuste 0.42044202084557997
# Optimizando ventana: 2020-05-25 al 2020-06-19
# Resultado obtenido entrenando desde 2020-05-25 hasta 2020-06-19
# Método: TRIMA, Datos optimizados [np.int64(13), np.int64(61)]
#
# hit ratio: 0.8428571428571429
# risk reward: 0.3235379670949499
# profit factor: 2.120971117622449
# trades: 70
# Resultado de sobre ajuste 1.1005514022839085
# Optimizando ventana: 2020-06-01 al 2020-06-26
# Resultado obtenido entrenando desde 2020-06-01 hasta 2020-06-26
# Método: WMA, Datos optimizados [np.int64(20), np.int64(23)]
#
# hit ratio: 0.780952380952381
# risk reward: 0.37219772242146176
# profit factor: 1.3269657929808638
# trades: 105
# Resultado de sobre ajuste 0.1283303011445624
# Optimizando ventana: 2020-06-08 al 2020-07-03
# Resultado obtenido entrenando desde 2020-06-08 hasta 2020-07-03
# Método: SMA, Datos optimizados [np.int64(20), np.int64(20)]
#
# hit ratio: 0.782608695652174
# risk reward: 0.30521801286633027
# profit factor: 1.220872051465321
# trades: 92
# Resultado de sobre ajuste -0.5907067648441824
# Optimizando ventana: 2020-06-15 al 2020-07-10
# Resultado obtenido entrenando desde 2020-06-15 hasta 2020-07-10
# Método: TRIMA, Datos optimizados [np.int64(10), np.int64(7)]
#
# hit ratio: 0.6805111821086262
# risk reward: 0.5117409358513543
# profit factor: 1.1237197869725617
# trades: 313
# Resultado de sobre ajuste 0.36628078229628114
# Optimizando ventana: 2020-06-22 al 2020-07-17
# Resultado obtenido entrenando desde 2020-06-22 hasta 2020-07-17
# Método: T3, Datos optimizados [np.int64(16), np.int64(98)]
#
# hit ratio: 0.8888888888888888
# risk reward: 3.6593750000004373
# profit factor: 29.275000000003498
# trades: 18
# Resultado de sobre ajuste -0.2180096782752143
# Optimizando ventana: 2020-06-29 al 2020-07-24
# Resultado obtenido entrenando desde 2020-06-29 hasta 2020-07-24
# Método: T3, Datos optimizados [np.int64(6), np.int64(54)]
#
# hit ratio: 0.8173913043478261
# risk reward: 0.3268617021276673
# profit factor: 1.617105263157933
# trades: 115
# Resultado de sobre ajuste 1.1793944361737017
# Optimizando ventana: 2020-07-06 al 2020-07-31
# Resultado obtenido entrenando desde 2020-07-06 hasta 2020-07-31
# Método: T3, Datos optimizados [np.int64(17), np.int64(90)]
#
# hit ratio: 0.96875
# risk reward: 2.7336641852778034
# profit factor: 84.7435897436119
# trades: 32
# Resultado de sobre ajuste 1.0190603433642251
# Optimizando ventana: 2020-07-13 al 2020-08-07
# Resultado obtenido entrenando desde 2020-07-13 hasta 2020-08-07
# Método: T3, Datos optimizados [np.int64(15), np.int64(82)]
#
# hit ratio: 0.9523809523809523
# risk reward: 0.264589905362777
# profit factor: 5.2917981072555405
# trades: 42
# Resultado de sobre ajuste 1.3028345922666427
# Optimizando ventana: 2020-07-20 al 2020-08-14
# Resultado obtenido entrenando desde 2020-07-20 hasta 2020-08-14
# Método: TEMA, Datos optimizados [np.int64(19), np.int64(16)]
#
# hit ratio: 0.6871165644171779
# risk reward: 0.6016689181582989
# profit factor: 1.464933018124554
# trades: 163
# Resultado de sobre ajuste 1.2733945038922345
# Optimizando ventana: 2020-07-27 al 2020-08-21
# Resultado obtenido entrenando desde 2020-07-27 hasta 2020-08-21
# Método: TEMA, Datos optimizados [np.int64(6), np.int64(67)]
#
# hit ratio: 0.7760617760617761
# risk reward: 0.3390749910424296
# profit factor: 1.3106552538370837
# trades: 259
# Resultado de sobre ajuste 0.3074821489582318
# Optimizando ventana: 2020-08-03 al 2020-08-28
# Resultado obtenido entrenando desde 2020-08-03 hasta 2020-08-28
# Método: EMA, Datos optimizados [np.int64(12), np.int64(19)]
#
# hit ratio: 0.7916666666666666
# risk reward: 0.35659550876776064
# profit factor: 1.3949177254738871
# trades: 168
# Resultado de sobre ajuste -0.217487675329039
# Optimizando ventana: 2020-08-10 al 2020-09-04
# Resultado obtenido entrenando desde 2020-08-10 hasta 2020-09-04
# Método: TEMA, Datos optimizados [np.int64(9), np.int64(34)]
#
# hit ratio: 0.7169811320754716
# risk reward: 0.5289334814609135
# profit factor: 1.4779023746701991
# trades: 265
# Resultado de sobre ajuste 0.8534600990579005
# Optimizando ventana: 2020-08-17 al 2020-09-11
# Resultado obtenido entrenando desde 2020-08-17 hasta 2020-09-11
# Método: SMA, Datos optimizados [np.int64(7), np.int64(32)]
#
# hit ratio: 0.805
# risk reward: 0.3292286580961956
# profit factor: 1.4723837209302082
# trades: 200
# Resultado de sobre ajuste 0.6892495942937202
# Optimizando ventana: 2020-08-24 al 2020-09-18
# Resultado obtenido entrenando desde 2020-08-24 hasta 2020-09-18
# Método: EMA, Datos optimizados [np.int64(16), np.int64(35)]
#
# hit ratio: 0.8260869565217391
# risk reward: 0.26605218630331967
# profit factor: 1.3479977439368196
# trades: 92
# Resultado de sobre ajuste 0.55748014669129
# Optimizando ventana: 2020-08-31 al 2020-09-25
# Resultado obtenido entrenando desde 2020-08-31 hasta 2020-09-25
# Método: EMA, Datos optimizados [np.int64(10), np.int64(6)]
#
# hit ratio: 0.7264957264957265
# risk reward: 0.38701155462184134
# profit factor: 1.061160714285694
# trades: 351
# Resultado de sobre ajuste -0.2029849990892826
# Optimizando ventana: 2020-09-07 al 2020-10-02
# Resultado obtenido entrenando desde 2020-09-07 hasta 2020-10-02
# Método: WMA, Datos optimizados [np.int64(2), np.int64(85)]
#
# hit ratio: 0.842756183745583
# risk reward: 0.23386219225462374
# profit factor: 1.3771884654994508
# trades: 566
# Resultado de sobre ajuste 0.3614976275606022
# Optimizando ventana: 2020-09-14 al 2020-10-09
# Resultado obtenido entrenando desde 2020-09-14 hasta 2020-10-09
# Método: TEMA, Datos optimizados [np.int64(17), np.int64(36)]
#
# hit ratio: 0.7555555555555555
# risk reward: 0.448395428423847
# profit factor: 1.3859495060373455
# trades: 135
# Resultado de sobre ajuste 0.8151674211102828
# Optimizando ventana: 2020-09-21 al 2020-10-16
# Resultado obtenido entrenando desde 2020-09-21 hasta 2020-10-16
# Método: DEMA, Datos optimizados [np.int64(16), np.int64(26)]
#
# hit ratio: 0.7218543046357616
# risk reward: 0.576086324577607
# profit factor: 1.5698352344739792
# trades: 151
# Resultado de sobre ajuste 1.5297001048495655
# Optimizando ventana: 2020-09-28 al 2020-10-23
# Resultado obtenido entrenando desde 2020-09-28 hasta 2020-10-23
# Método: SMA, Datos optimizados [np.int64(18), np.int64(15)]
#
# hit ratio: 0.8015267175572519
# risk reward: 0.4835555555555647
# profit factor: 2.115555555555596
# trades: 131
# Resultado de sobre ajuste 2.1387128717224364
# Optimizando ventana: 2020-10-05 al 2020-10-30
# Resultado obtenido entrenando desde 2020-10-05 hasta 2020-10-30
# Método: T3, Datos optimizados [np.int64(11), np.int64(10)]
#
# hit ratio: 0.7142857142857143
# risk reward: 0.44788715664438467
# profit factor: 1.2919821826280327
# trades: 210
# Resultado de sobre ajuste 0.4297055195949884
# Optimizando ventana: 2020-10-12 al 2020-11-06
# Resultado obtenido entrenando desde 2020-10-12 hasta 2020-11-06
# Método: KAMA, Datos optimizados [np.int64(5), np.int64(34)]
#
# hit ratio: 0.8233082706766918
# risk reward: 0.23960488634547022
# profit factor: 1.1660771135479548
# trades: 266
# Resultado de sobre ajuste -0.5753579616226964
# Optimizando ventana: 2020-10-19 al 2020-11-13
# Resultado obtenido entrenando desde 2020-10-19 hasta 2020-11-13
# Método: T3, Datos optimizados [np.int64(2), np.int64(8)]
#
# hit ratio: 0.7305619707467282
# risk reward: 0.4536203405909565
# profit factor: 1.2850319499128888
# trades: 1299
# Resultado de sobre ajuste 0.21855256813013615
# Optimizando ventana: 2020-10-26 al 2020-11-20
# Resultado obtenido entrenando desde 2020-10-26 hasta 2020-11-20
# Método: TRIMA, Datos optimizados [np.int64(15), np.int64(107)]
#
# hit ratio: 0.8392857142857143
# risk reward: 0.27589882343295274
# profit factor: 1.6209055876685974
# trades: 56
# Resultado de sobre ajuste 0.4246508945060878
# Optimizando ventana: 2020-11-02 al 2020-11-27
# Resultado obtenido entrenando desde 2020-11-02 hasta 2020-11-27
# Método: TRIMA, Datos optimizados [np.int64(14), np.int64(89)]
#
# hit ratio: 0.7818181818181819
# risk reward: 0.5503649964969468
# profit factor: 2.9582118561710895
# trades: 55
# Resultado de sobre ajuste 0.6603559005549863
# Optimizando ventana: 2020-11-09 al 2020-12-04
# Resultado obtenido entrenando desde 2020-11-09 hasta 2020-12-04
# Método: T3, Datos optimizados [np.int64(17), np.int64(97)]
#
# hit ratio: 0.9032258064516129
# risk reward: 3.4902597402579874
# profit factor: 97.72727272722364
# trades: 31
# Resultado de sobre ajuste 2.799021474603891
# Optimizando ventana: 2020-11-16 al 2020-12-11
# Resultado obtenido entrenando desde 2020-11-16 hasta 2020-12-11
# Método: T3, Datos optimizados [np.int64(14), np.int64(54)]
#
# hit ratio: 0.8260869565217391
# risk reward: 0.7245423340961055
# profit factor: 3.9332298136645725
# trades: 46
# Resultado de sobre ajuste 1.70206571262589
# Optimizando ventana: 2020-11-23 al 2020-12-18
# Resultado obtenido entrenando desde 2020-11-23 hasta 2020-12-18
# Método: MIDPOINT, Datos optimizados [np.int64(13), np.int64(104)]
#
# hit ratio: 0.8367346938775511
# risk reward: 0.36311318169362405
# profit factor: 2.9775280898877177
# trades: 49
# Resultado de sobre ajuste 2.169910874343068
# Optimizando ventana: 2020-11-30 al 2020-12-25
# Resultado obtenido entrenando desde 2020-11-30 hasta 2020-12-24
# Método: KAMA, Datos optimizados [np.int64(17), np.int64(53)]
#
# hit ratio: 0.918918918918919
# risk reward: 0.41156325543917477
# profit factor: 4.664383561643981
# trades: 74
# Resultado de sobre ajuste 0.464831161938779
# Optimizando ventana: 2020-12-07 al 2021-01-01
# Resultado obtenido entrenando desde 2020-12-07 hasta 2020-12-31
# Método: EMA, Datos optimizados [np.int64(15), np.int64(97)]
#
# hit ratio: 0.8888888888888888
# risk reward: 0.47480254120878873
# profit factor: 4.431490384615362
# trades: 63
# Resultado de sobre ajuste 2.13548068962917
# Optimizando ventana: 2020-12-14 al 2021-01-08
# Resultado obtenido entrenando desde 2020-12-14 hasta 2021-01-08
# Método: EMA, Datos optimizados [np.int64(12), np.int64(105)]
#
# hit ratio: 0.9178082191780822
# risk reward: 0.3582089552238865
# profit factor: 4.000000000000067
# trades: 73
# Resultado de sobre ajuste 0.9767855515918048
# Optimizando ventana: 2020-12-21 al 2021-01-15
# Resultado obtenido entrenando desde 2020-12-21 hasta 2021-01-15
# Método: KAMA, Datos optimizados [np.int64(7), np.int64(58)]
#
# hit ratio: 0.8456375838926175
# risk reward: 0.22811129563541138
# profit factor: 1.3064556022755378
# trades: 149
# Resultado de sobre ajuste -0.35472346724720544
# Optimizando ventana: 2020-12-28 al 2021-01-22
# Resultado obtenido entrenando desde 2020-12-28 hasta 2021-01-22
# Método: EMA, Datos optimizados [np.int64(10), np.int64(9)]
#
# hit ratio: 0.7900355871886121
# risk reward: 0.3297259829145163
# profit factor: 1.2841959334565374
# trades: 281
# Resultado de sobre ajuste 0.18346022862787204
# Optimizando ventana: 2021-01-04 al 2021-01-29
# Resultado obtenido entrenando desde 2021-01-04 hasta 2021-01-29
# Método: MIDPOINT, Datos optimizados [np.int64(14), np.int64(73)]
#
# hit ratio: 0.7692307692307693
# risk reward: 0.33222859190255916
# profit factor: 1.3289143676102366
# trades: 78
# Resultado de sobre ajuste 0.2552931479895096
# Optimizando ventana: 2021-01-11 al 2021-02-05
# Resultado obtenido entrenando desde 2021-01-11 hasta 2021-02-05
# Método: WMA, Datos optimizados [np.int64(20), np.int64(65)]
#
# hit ratio: 0.7666666666666667
# risk reward: 0.27453996633192523
# profit factor: 1.05240320427238
# trades: 60
# Resultado de sobre ajuste -0.018288360414804004
# Optimizando ventana: 2021-01-18 al 2021-02-12
# Resultado obtenido entrenando desde 2021-01-18 hasta 2021-02-12
# Método: WMA, Datos optimizados [np.int64(9), np.int64(8)]
#
# hit ratio: 0.7329974811083123
# risk reward: 0.452191824447465
# profit factor: 1.2775516593612846
# trades: 397
# Resultado de sobre ajuste 0.41307844210205186
# Optimizando ventana: 2021-01-25 al 2021-02-19
# Resultado obtenido entrenando desde 2021-01-25 hasta 2021-02-19
# Método: TEMA, Datos optimizados [np.int64(1), np.int64(91)]
#
# hit ratio: 0.7642611683848797
# risk reward: 0.3496844108010819
# profit factor: 1.2305350152240602
# trades: 1455
# Resultado de sobre ajuste -0.08632550251571108
# Optimizando ventana: 2021-02-01 al 2021-02-26
# Resultado obtenido entrenando desde 2021-02-01 hasta 2021-02-26
# Método: TEMA, Datos optimizados [np.int64(20), np.int64(51)]
#
# hit ratio: 0.7469879518072289
# risk reward: 0.5209621220636175
# profit factor: 1.6149825783972143
# trades: 83
# Resultado de sobre ajuste 0.8537868579743068
# Optimizando ventana: 2021-02-08 al 2021-03-05
# Resultado obtenido entrenando desde 2021-02-08 hasta 2021-03-05
# Método: TRIMA, Datos optimizados [np.int64(18), np.int64(17)]
#
# hit ratio: 0.7431192660550459
# risk reward: 0.3756714923062859
# profit factor: 1.1270144769188575
# trades: 109
# Resultado de sobre ajuste -0.2046112418743533
# Optimizando ventana: 2021-02-15 al 2021-03-12
# Resultado obtenido entrenando desde 2021-02-15 hasta 2021-03-12
# Método: TEMA, Datos optimizados [np.int64(17), np.int64(72)]
#
# hit ratio: 0.7340425531914894
# risk reward: 0.4294800467065058
# profit factor: 1.2347551342812042
# trades: 94
# Resultado de sobre ajuste -0.269944844059931
# Optimizando ventana: 2021-02-22 al 2021-03-19
# Resultado obtenido entrenando desde 2021-02-22 hasta 2021-03-19
# Método: SMA, Datos optimizados [np.int64(1), np.int64(7)]
#
# hit ratio: 0.6997046275024614
# risk reward: 0.4289427068267532
# profit factor: 1.095216587969626
# trades: 3047
# Resultado de sobre ajuste -0.1539163000491502
# Optimizando ventana: 2021-03-01 al 2021-03-26
# Resultado obtenido entrenando desde 2021-03-01 hasta 2021-03-26
# Método: WMA, Datos optimizados [np.int64(1), np.int64(7)]
#
# hit ratio: 0.6681391496410822
# risk reward: 0.4591622243779785
# profit factor: 1.0175573104347142
# trades: 3622
# Resultado de sobre ajuste -0.5880149658231502
# Optimizando ventana: 2021-03-08 al 2021-04-02
# Resultado obtenido entrenando desde 2021-03-08 hasta 2021-04-02
# Método: MIDPOINT, Datos optimizados [np.int64(5), np.int64(69)]
#
# hit ratio: 0.7865168539325843
# risk reward: 0.28130996636571254
# profit factor: 1.2307311028499923
# trades: 178
# Resultado de sobre ajuste 0.17594599221126977
# Optimizando ventana: 2021-03-15 al 2021-04-09
# Resultado obtenido entrenando desde 2021-03-15 hasta 2021-04-09
# Método: MIDPOINT, Datos optimizados [np.int64(5), np.int64(26)]
#
# hit ratio: 0.7397769516728625
# risk reward: 0.42424525072101604
# profit factor: 1.2600717148280924
# trades: 269
# Resultado de sobre ajuste -0.01752408464112097
# Optimizando ventana: 2021-03-22 al 2021-04-16
# Resultado obtenido entrenando desde 2021-03-22 hasta 2021-04-16
# Método: T3, Datos optimizados [np.int64(17), np.int64(110)]
#
# hit ratio: 0.88
# risk reward: 4.946708463951634
# profit factor: 54.413793103467974
# trades: 25
# Resultado de sobre ajuste -0.02161753635948393
# Optimizando ventana: 2021-03-29 al 2021-04-23
# Resultado obtenido entrenando desde 2021-03-29 hasta 2021-04-23
# Método: T3, Datos optimizados [np.int64(15), np.int64(99)]
#
# hit ratio: 0.8888888888888888
# risk reward: 5.176666666664805
# profit factor: 62.11999999997765
# trades: 27
# Resultado de sobre ajuste 2.0659744130987026
# Optimizando ventana: 2021-04-05 al 2021-04-30
# Resultado obtenido entrenando desde 2021-04-05 hasta 2021-04-30
# Método: MIDPOINT, Datos optimizados [np.int64(15), np.int64(101)]
#
# hit ratio: 0.7727272727272727
# risk reward: 0.85146237265867
# profit factor: 4.8249534450657965
# trades: 44
# Resultado de sobre ajuste 1.5933487125738461
# Optimizando ventana: 2021-04-12 al 2021-05-07
# Resultado obtenido entrenando desde 2021-04-12 hasta 2021-05-07
# Método: WMA, Datos optimizados [np.int64(12), np.int64(22)]
#
# hit ratio: 0.7592592592592593
# risk reward: 0.3668767946136889
# profit factor: 1.2893098782138208
# trades: 162
# Resultado de sobre ajuste -0.9198073606376878
# Optimizando ventana: 2021-04-19 al 2021-05-14
# Resultado obtenido entrenando desde 2021-04-19 hasta 2021-05-13
# Método: MIDPOINT, Datos optimizados [np.int64(15), np.int64(28)]
#
# hit ratio: 0.7402597402597403
# risk reward: 0.36611380931928506
# profit factor: 1.2275580665411323
# trades: 77
# Resultado de sobre ajuste 0.199167542665873
# Optimizando ventana: 2021-04-26 al 2021-05-21
# Resultado obtenido entrenando desde 2021-04-26 hasta 2021-05-20
# Método: WMA, Datos optimizados [np.int64(15), np.int64(12)]
#
# hit ratio: 0.7257142857142858
# risk reward: 0.4793654167195108
# profit factor: 1.3234653896386492
# trades: 175
# Resultado de sobre ajuste 0.6001463699656125
# Optimizando ventana: 2021-05-03 al 2021-05-28
# Resultado obtenido entrenando desde 2021-05-03 hasta 2021-05-27
# Método: KAMA, Datos optimizados [np.int64(11), np.int64(65)]
#
# hit ratio: 0.898989898989899
# risk reward: 0.22218744390077724
# profit factor: 1.9774682507169175
# trades: 99
# Resultado de sobre ajuste 1.3786402420576025
# Optimizando ventana: 2021-05-10 al 2021-06-04
# Resultado obtenido entrenando desde 2021-05-10 hasta 2021-06-03
# Método: SMA, Datos optimizados [np.int64(14), np.int64(38)]
#
# hit ratio: 0.8173076923076923
# risk reward: 0.2877996524388862
# profit factor: 1.528935653581583
# trades: 104
# Resultado de sobre ajuste -0.6506195771345562
# Optimizando ventana: 2021-05-17 al 2021-06-11
# Resultado obtenido entrenando desde 2021-05-17 hasta 2021-06-10
# Método: SMA, Datos optimizados [np.int64(18), np.int64(75)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.2527899078117476
# profit factor: 1.625077978789806
# trades: 54
# Resultado de sobre ajuste -0.1522255946422125
# Optimizando ventana: 2021-05-24 al 2021-06-18
# Resultado obtenido entrenando desde 2021-05-24 hasta 2021-06-17
# Método: T3, Datos optimizados [np.int64(13), np.int64(70)]
#
# hit ratio: 0.9107142857142857
# risk reward: 0.12172417043741146
# profit factor: 1.241586538461597
# trades: 56
# Resultado de sobre ajuste -0.2594325057337239
# Optimizando ventana: 2021-05-31 al 2021-06-25
# Resultado obtenido entrenando desde 2021-05-31 hasta 2021-06-24
# Método: SMA, Datos optimizados [np.int64(9), np.int64(4)]
#
# hit ratio: 0.6334012219959266
# risk reward: 0.5858079691974647
# profit factor: 1.0654168328679037
# trades: 491
# Resultado de sobre ajuste -0.828779345739243
# Optimizando ventana: 2021-06-07 al 2021-07-02
# Resultado obtenido entrenando desde 2021-06-07 hasta 2021-07-01
# Método: TEMA, Datos optimizados [np.int64(1), np.int64(97)]
#
# hit ratio: 0.7531044558071585
# risk reward: 0.3301199880431844
# profit factor: 1.094384912130299
# trades: 1369
# Resultado de sobre ajuste 0.06957563286719948
# Optimizando ventana: 2021-06-14 al 2021-07-09
# Resultado obtenido entrenando desde 2021-06-14 hasta 2021-07-08
# Método: TEMA, Datos optimizados [np.int64(1), np.int64(53)]
#
# hit ratio: 0.7160362280234417
# risk reward: 0.36442931793177985
# profit factor: 1.0289768976897313
# trades: 1877
# Resultado de sobre ajuste -0.008261358332132072
# Optimizando ventana: 2021-06-21 al 2021-07-16
# Resultado obtenido entrenando desde 2021-06-21 hasta 2021-07-15
# Método: MIDPOINT, Datos optimizados [np.int64(15), np.int64(89)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.2656156071003228
# profit factor: 1.6232064878353056
# trades: 66
# Resultado de sobre ajuste 0.2036680779264408
# Optimizando ventana: 2021-06-28 al 2021-07-23
# Resultado obtenido entrenando desde 2021-06-28 hasta 2021-07-22
# Método: WMA, Datos optimizados [np.int64(19), np.int64(108)]
#
# hit ratio: 0.7719298245614035
# risk reward: 0.40574963609901926
# profit factor: 1.7852983988356848
# trades: 57
# Resultado de sobre ajuste 0.8041846755749833
# Optimizando ventana: 2021-07-05 al 2021-07-30
# Resultado obtenido entrenando desde 2021-07-05 hasta 2021-07-29
# Método: TRIMA, Datos optimizados [np.int64(12), np.int64(14)]
#
# hit ratio: 0.7336956521739131
# risk reward: 0.5014646689412763
# profit factor: 1.5385847797061887
# trades: 184
# Resultado de sobre ajuste 0.6492568982198872
# Optimizando ventana: 2021-07-12 al 2021-08-06
# Resultado obtenido entrenando desde 2021-07-12 hasta 2021-08-05
# Método: DEMA, Datos optimizados [np.int64(19), np.int64(52)]
#
# hit ratio: 0.7931034482758621
# risk reward: 0.586754823538682
# profit factor: 2.3815342837746507
# trades: 87
# Resultado de sobre ajuste 2.6828481387633096
# Optimizando ventana: 2021-07-19 al 2021-08-13
# Resultado obtenido entrenando desde 2021-07-19 hasta 2021-08-12
# Método: TRIMA, Datos optimizados [np.int64(9), np.int64(78)]
#
# hit ratio: 0.8305084745762712
# risk reward: 0.3965161822304682
# profit factor: 2.0451887293992566
# trades: 118
# Resultado de sobre ajuste 0.09368677621916419
# Optimizando ventana: 2021-07-26 al 2021-08-20
# Resultado obtenido entrenando desde 2021-07-26 hasta 2021-08-19
# Método: WMA, Datos optimizados [np.int64(6), np.int64(93)]
#
# hit ratio: 0.8296703296703297
# risk reward: 0.23453661281585686
# profit factor: 1.311667723525718
# trades: 182
# Resultado de sobre ajuste -0.03854253302739438
# Optimizando ventana: 2021-08-02 al 2021-08-27
# Resultado obtenido entrenando desde 2021-08-02 hasta 2021-08-26
# Método: TRIMA, Datos optimizados [np.int64(5), np.int64(56)]
#
# hit ratio: 0.8169642857142857
# risk reward: 0.29591212745003925
# profit factor: 1.4635653871177619
# trades: 224
# Resultado de sobre ajuste 0.4798665520810932
# Optimizando ventana: 2021-08-09 al 2021-09-03
# Resultado obtenido entrenando desde 2021-08-09 hasta 2021-09-02
# Método: T3, Datos optimizados [np.int64(19), np.int64(63)]
#
# hit ratio: 0.9111111111111111
# risk reward: 0.3117678476054818
# profit factor: 3.1956204379561886
# trades: 45
# Resultado de sobre ajuste 1.5576967044985999
# Optimizando ventana: 2021-08-16 al 2021-09-10
# Resultado obtenido entrenando desde 2021-08-16 hasta 2021-09-09
# Método: DEMA, Datos optimizados [np.int64(17), np.int64(85)]
#
# hit ratio: 0.8
# risk reward: 0.758959537572299
# profit factor: 3.269364161849903
# trades: 70
# Resultado de sobre ajuste 3.289936477808429
# Optimizando ventana: 2021-08-23 al 2021-09-17
# Resultado obtenido entrenando desde 2021-08-23 hasta 2021-09-16
# Método: T3, Datos optimizados [np.int64(14), np.int64(63)]
#
# hit ratio: 0.8421052631578947
# risk reward: 0.5350344268935039
# profit factor: 3.2102065613610233
# trades: 57
# Resultado de sobre ajuste 1.345108735797521
# Optimizando ventana: 2021-08-30 al 2021-09-24
# Resultado obtenido entrenando desde 2021-08-30 hasta 2021-09-23
# Método: EMA, Datos optimizados [np.int64(4), np.int64(63)]
#
# hit ratio: 0.8451612903225807
# risk reward: 0.2541818933387253
# profit factor: 1.5135376376078642
# trades: 310
# Resultado de sobre ajuste -0.3044072392148353
# Optimizando ventana: 2021-09-06 al 2021-10-01
# Resultado obtenido entrenando desde 2021-09-06 hasta 2021-09-30
# Método: TRIMA, Datos optimizados [np.int64(3), np.int64(110)]
#
# hit ratio: 0.8302583025830258
# risk reward: 0.2018522941379382
# profit factor: 1.1354191545259025
# trades: 271
# Resultado de sobre ajuste -0.0885578759944962
# Optimizando ventana: 2021-09-13 al 2021-10-08
# Resultado obtenido entrenando desde 2021-09-13 hasta 2021-10-07
# Método: WMA, Datos optimizados [np.int64(2), np.int64(47)]
#
# hit ratio: 0.7849740932642487
# risk reward: 0.27755509273799395
# profit factor: 1.1599888703394783
# trades: 772
# Resultado de sobre ajuste -0.3304940300961638
# Optimizando ventana: 2021-09-20 al 2021-10-15
# Resultado obtenido entrenando desde 2021-09-20 hasta 2021-10-14
# Método: EMA, Datos optimizados [np.int64(13), np.int64(37)]
#
# hit ratio: 0.8062015503875969
# risk reward: 0.327870794503237
# profit factor: 1.482546201232028
# trades: 129
# Resultado de sobre ajuste 0.8673541212038423
# Optimizando ventana: 2021-09-27 al 2021-10-22
# Resultado obtenido entrenando desde 2021-09-27 hasta 2021-10-21
# Método: KAMA, Datos optimizados [np.int64(6), np.int64(100)]
#
# hit ratio: 0.8627450980392157
# risk reward: 0.21163208663209176
# profit factor: 1.3967717717718058
# trades: 153
# Resultado de sobre ajuste -0.04666792617482163
# Optimizando ventana: 2021-10-04 al 2021-10-29
# Resultado obtenido entrenando desde 2021-10-04 hasta 2021-10-28
# Método: T3, Datos optimizados [np.int64(20), np.int64(86)]
#
# hit ratio: 0.8205128205128205
# risk reward: 0.6061046511629141
# profit factor: 3.232558139535542
# trades: 39
# Resultado de sobre ajuste 0.7522672640104062
# Optimizando ventana: 2021-10-11 al 2021-11-05
# Resultado obtenido entrenando desde 2021-10-11 hasta 2021-11-04
# Método: TRIMA, Datos optimizados [np.int64(10), np.int64(109)]
#
# hit ratio: 0.8412698412698413
# risk reward: 0.24183461978274104
# profit factor: 1.2817234848485277
# trades: 63
# Resultado de sobre ajuste -0.1986716402848207
# Optimizando ventana: 2021-10-18 al 2021-11-12
# Resultado obtenido entrenando desde 2021-10-18 hasta 2021-11-11
# Método: EMA, Datos optimizados [np.int64(11), np.int64(86)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.2595851742758886
# profit factor: 1.3977663230240156
# trades: 84
# Resultado de sobre ajuste -0.8006094578451753
# Optimizando ventana: 2021-10-25 al 2021-11-19
# Resultado obtenido entrenando desde 2021-10-25 hasta 2021-11-18
# Método: SMA, Datos optimizados [np.int64(4), np.int64(13)]
#
# hit ratio: 0.738819320214669
# risk reward: 0.32536044280864246
# profit factor: 0.9667184379853909
# trades: 559
# Resultado de sobre ajuste -0.13620649046556155
# Optimizando ventana: 2021-11-01 al 2021-11-26
# Resultado obtenido entrenando desde 2021-11-01 hasta 2021-11-25
# Método: DEMA, Datos optimizados [np.int64(3), np.int64(63)]
#
# hit ratio: 0.7863894139886578
# risk reward: 0.27094487543707596
# profit factor: 1.0734577922078437
# trades: 529
# Resultado de sobre ajuste 0.18775639389923648
# Optimizando ventana: 2021-11-08 al 2021-12-03
# ...
# risk reward: 0.4447270471464088
# profit factor: 2.2236352357320435
# trades: 72
# Resultado de sobre ajuste 1.2589042886706316
# Optimizando ventana: 2025-02-17 al 2025-03-14
# Resultado obtenido entrenando desde 2025-02-17 hasta 2025-03-14
# Método: EMA, Datos optimizados [np.int64(9), np.int64(51)]
#
# hit ratio: 0.8156028368794326
# risk reward: 0.38261796936583053
# profit factor: 1.7600426590828204
# trades: 141
# Resultado de sobre ajuste 1.0439205189970706
# Optimizando ventana: 2025-02-24 al 2025-03-21
# Resultado obtenido entrenando desde 2025-02-24 hasta 2025-03-21
# Método: MIDPOINT, Datos optimizados [np.int64(14), np.int64(68)]
#
# hit ratio: 0.8356164383561644
# risk reward: 0.33182014939452886
# profit factor: 2.5301286391332822
# trades: 73
# Resultado de sobre ajuste 1.24499389114731
# Optimizando ventana: 2025-03-03 al 2025-03-28
# Resultado obtenido entrenando desde 2025-03-03 hasta 2025-03-28
# Método: MIDPOINT, Datos optimizados [np.int64(10), np.int64(108)]
#
# hit ratio: 0.8314606741573034
# risk reward: 0.4077868700432451
# profit factor: 2.5146856986000112
# trades: 89
# Resultado de sobre ajuste 2.040561742115525
# Optimizando ventana: 2025-03-10 al 2025-04-04
# Resultado obtenido entrenando desde 2025-03-10 hasta 2025-04-04
# Método: KAMA, Datos optimizados [np.int64(5), np.int64(70)]
#
# hit ratio: 0.8108108108108109
# risk reward: 0.33267563527653976
# profit factor: 1.4257527226137419
# trades: 185
# Resultado de sobre ajuste 0.7766199169035111
# Optimizando ventana: 2025-03-17 al 2025-04-11
# Resultado obtenido entrenando desde 2025-03-17 hasta 2025-04-11
# Método: WMA, Datos optimizados [np.int64(17), np.int64(80)]
#
# hit ratio: 0.7857142857142857
# risk reward: 0.4509935819319359
# profit factor: 1.7717605004468913
# trades: 70
# Resultado de sobre ajuste 0.5390523906599557
# Optimizando ventana: 2025-03-24 al 2025-04-18
# Resultado obtenido entrenando desde 2025-03-24 hasta 2025-04-18
# Método: EMA, Datos optimizados [np.int64(17), np.int64(67)]
#
# hit ratio: 0.803030303030303
# risk reward: 0.688997652881107
# profit factor: 3.043072966891556
# trades: 66
# Resultado de sobre ajuste 1.7739956332879987
# Optimizando ventana: 2025-03-31 al 2025-04-25
# Resultado obtenido entrenando desde 2025-03-31 hasta 2025-04-25
# Método: EMA, Datos optimizados [np.int64(19), np.int64(81)]
#
# hit ratio: 0.8333333333333334
# risk reward: 0.42158896753722974
# profit factor: 2.409079814498456
# trades: 48
# Resultado de sobre ajuste 1.3561199428312503
# Optimizando ventana: 2025-04-07 al 2025-05-02
# Resultado obtenido entrenando desde 2025-04-07 hasta 2025-05-02
# Método: EMA, Datos optimizados [np.int64(13), np.int64(109)]
#
# hit ratio: 0.9027777777777778
# risk reward: 0.28264299802760806
# profit factor: 3.0619658119657536
# trades: 72
# Resultado de sobre ajuste 0.5388456524630323
# Optimizando ventana: 2025-04-14 al 2025-05-09
# Resultado obtenido entrenando desde 2025-04-14 hasta 2025-05-09
# Método: EMA, Datos optimizados [np.int64(15), np.int64(31)]
#
# hit ratio: 0.7927927927927928
# risk reward: 0.3970069907569972
# profit factor: 1.5189832689832936
# trades: 111
# Resultado de sobre ajuste 0.37104493040561204
# Optimizando ventana: 2025-04-21 al 2025-05-16
# Resultado obtenido entrenando desde 2025-04-21 hasta 2025-05-16
# Método: T3, Datos optimizados [np.int64(17), np.int64(26)]
#
# hit ratio: 0.7662337662337663
# risk reward: 0.3591314066877512
# profit factor: 1.3242970621610826
# trades: 77
# Resultado de sobre ajuste 0.06090142577073823
# Optimizando ventana: 2025-04-28 al 2025-05-23
# Resultado obtenido entrenando desde 2025-04-28 hasta 2025-05-23
# Método: KAMA, Datos optimizados [np.int64(20), np.int64(39)]
#
# hit ratio: 0.8169014084507042
# risk reward: 0.31344263902165015
# profit factor: 1.3984363894812084
# trades: 71
# Resultado de sobre ajuste 0.3814994495447008
# Optimizando ventana: 2025-05-05 al 2025-05-30
# Resultado obtenido entrenando desde 2025-05-05 hasta 2025-05-30
# Método: TRIMA, Datos optimizados [np.int64(6), np.int64(4)]
#
# hit ratio: 0.6960907944514502
# risk reward: 0.5678732703387577
# profit factor: 1.34534783359225
# trades: 793
# Resultado de sobre ajuste 0.6656287385929986
# Optimizando ventana: 2025-05-12 al 2025-06-06
# Resultado obtenido entrenando desde 2025-05-12 hasta 2025-06-06
# Método: MIDPOINT, Datos optimizados [np.int64(17), np.int64(87)]
#
# hit ratio: 0.7916666666666666
# risk reward: 0.2318299474468623
# profit factor: 1.468256333830128
# trades: 48
# Resultado de sobre ajuste 0.6923616689788219
# Optimizando ventana: 2025-05-19 al 2025-06-13
# Resultado obtenido entrenando desde 2025-05-19 hasta 2025-06-13
# Método: DEMA, Datos optimizados [np.int64(12), np.int64(58)]
#
# hit ratio: 0.7952755905511811
# risk reward: 0.4291949817432411
# profit factor: 1.7339477262426939
# trades: 127
# Resultado de sobre ajuste 1.967977272576193
# Optimizando ventana: 2025-05-26 al 2025-06-20
# Resultado obtenido entrenando desde 2025-05-26 hasta 2025-06-20
# Método: TEMA, Datos optimizados [np.int64(1), np.int64(65)]
#
# hit ratio: 0.7684210526315789
# risk reward: 0.36250028329535483
# profit factor: 1.2859025394645962
# trades: 1805
# Resultado de sobre ajuste 0.5595267183643936
# Optimizando ventana: 2025-06-02 al 2025-06-27
# Resultado obtenido entrenando desde 2025-06-02 hasta 2025-06-27
# Método: KAMA, Datos optimizados [np.int64(10), np.int64(92)]
#
# hit ratio: 0.900990099009901
# risk reward: 0.17823144463509774
# profit factor: 1.8021179401993217
# trades: 101
# Resultado de sobre ajuste 1.2547261280595245
# Optimizando ventana: 2025-06-09 al 2025-07-04
# Resultado obtenido entrenando desde 2025-06-09 hasta 2025-07-04
# Método: KAMA, Datos optimizados [np.int64(15), np.int64(90)]
#
# hit ratio: 0.9230769230769231
# risk reward: 0.31668769905655797
# profit factor: 4.5603028664144345
# trades: 78
# Resultado de sobre ajuste 1.1359826510667692
# Optimizando ventana: 2025-06-16 al 2025-07-11
# Resultado obtenido entrenando desde 2025-06-16 hasta 2025-07-11
# Método: KAMA, Datos optimizados [np.int64(16), np.int64(87)]
#
# hit ratio: 0.9076923076923077
# risk reward: 0.2599791591348881
# profit factor: 3.06775407779168
# trades: 65
# Resultado de sobre ajuste 0.7342149717570436
# Optimizando ventana: 2025-06-23 al 2025-07-18
# Resultado obtenido entrenando desde 2025-06-23 hasta 2025-07-18
# Método: KAMA, Datos optimizados [np.int64(19), np.int64(105)]
#
# hit ratio: 0.8360655737704918
# risk reward: 0.4516625802921833
# profit factor: 2.303479159490135
# trades: 61
# Resultado de sobre ajuste 0.34934153839905246
# Optimizando ventana: 2025-06-30 al 2025-07-25
# Resultado obtenido entrenando desde 2025-06-30 hasta 2025-07-25
# Método: KAMA, Datos optimizados [np.int64(14), np.int64(16)]
#
# hit ratio: 0.7803030303030303
# risk reward: 0.42898948602863624
# profit factor: 1.5780684664624833
# trades: 132
# Resultado de sobre ajuste -0.41174209494666275
# Optimizando ventana: 2025-07-07 al 2025-08-01
# Resultado obtenido entrenando desde 2025-07-07 hasta 2025-08-01
# Método: DEMA, Datos optimizados [np.int64(17), np.int64(81)]
#
# hit ratio: 0.75
# risk reward: 0.2700091996320237
# profit factor: 0.810027598896071
# trades: 64
# Resultado de sobre ajuste -0.39412097496467186
# Optimizando ventana: 2025-07-14 al 2025-08-08
# Resultado obtenido entrenando desde 2025-07-14 hasta 2025-08-08
# Método: DEMA, Datos optimizados [np.int64(8), np.int64(19)]
#
# hit ratio: 0.713855421686747
# risk reward: 0.42216541921132195
# profit factor: 1.0875348299248184
# trades: 332
# Resultado de sobre ajuste 0.2269748500907146
# Optimizando ventana: 2025-07-21 al 2025-08-15
# Resultado obtenido entrenando desde 2025-07-21 hasta 2025-08-15
# Método: MIDPOINT, Datos optimizados [np.int64(2), np.int64(63)]
#
# hit ratio: 0.8276553106212425
# risk reward: 0.25909524875590983
# profit factor: 1.2738849730498898
# trades: 499
# Resultado de sobre ajuste 0.2579857773646605
# Optimizando ventana: 2025-07-28 al 2025-08-22
# Resultado obtenido entrenando desde 2025-07-28 hasta 2025-08-22
# Método: DEMA, Datos optimizados [np.int64(12), np.int64(92)]
#
# hit ratio: 0.7849462365591398
# risk reward: 0.4084832480607356
# profit factor: 1.4909638554216849
# trades: 93
# Resultado de sobre ajuste 1.0474992579499975
# Optimizando ventana: 2025-08-04 al 2025-08-29
# Resultado obtenido entrenando desde 2025-08-04 hasta 2025-08-29
# Método: TRIMA, Datos optimizados [np.int64(18), np.int64(7)]
#
# hit ratio: 0.653179190751445
# risk reward: 0.6309977864406903
# profit factor: 1.250925436277158
# trades: 173
# Resultado de sobre ajuste -1.0436970962011367
# Optimizando ventana: 2025-08-11 al 2025-09-05
# Resultado obtenido entrenando desde 2025-08-11 hasta 2025-09-05
# Método: EMA, Datos optimizados [np.int64(15), np.int64(53)]
#
# hit ratio: 0.7285714285714285
# risk reward: 0.3935806036242603
# profit factor: 1.1151450436020707
# trades: 70
# Resultado de sobre ajuste 0.20159317627096046
# Optimizando ventana: 2025-08-18 al 2025-09-12
# Resultado obtenido entrenando desde 2025-08-18 hasta 2025-09-12
# Método: EMA, Datos optimizados [np.int64(12), np.int64(82)]
#
# hit ratio: 0.7727272727272727
# risk reward: 0.32047058823528196
# profit factor: 1.167428571428527
# trades: 66
# Resultado de sobre ajuste -0.241609635148702
# Optimizando ventana: 2025-08-25 al 2025-09-19
# Resultado obtenido entrenando desde 2025-08-25 hasta 2025-09-19
# Método: EMA, Datos optimizados [np.int64(18), np.int64(72)]
#
# hit ratio: 0.8541666666666666
# risk reward: 0.2619984264358777
# profit factor: 1.7903225806451641
# trades: 48
# Resultado de sobre ajuste 0.08189478734869213
# Optimizando ventana: 2025-09-01 al 2025-09-26
# Resultado obtenido entrenando desde 2025-09-01 hasta 2025-09-26
# Método: TRIMA, Datos optimizados [np.int64(18), np.int64(9)]
#
# hit ratio: 0.7407407407407407
# risk reward: 0.40736388562476494
# profit factor: 1.2220916568742948
# trades: 162
# Resultado de sobre ajuste 0.15566528708525237
# Optimizando ventana: 2025-09-08 al 2025-10-03
# Resultado obtenido entrenando desde 2025-09-08 hasta 2025-10-03
# Método: TEMA, Datos optimizados [np.int64(20), np.int64(84)]
#
# hit ratio: 0.7627118644067796
# risk reward: 0.48327004567718224
# profit factor: 1.6728578504210156
# trades: 59
# Resultado de sobre ajuste 0.3337495573021831
# Optimizando ventana: 2025-09-15 al 2025-10-10
# Resultado obtenido entrenando desde 2025-09-15 hasta 2025-10-10
# Método: T3, Datos optimizados [np.int64(8), np.int64(3)]
#
# hit ratio: 0.6612641815235009
# risk reward: 0.5206622724156064
# profit factor: 1.1006746484226289
# trades: 617
# Resultado de sobre ajuste -0.84572508628118
# Optimizando ventana: 2025-09-22 al 2025-10-17
# Resultado obtenido entrenando desde 2025-09-22 hasta 2025-10-17
# Método: KAMA, Datos optimizados [np.int64(2), np.int64(101)]
#
# hit ratio: 0.8496732026143791
# risk reward: 0.1969546049501408
# profit factor: 1.146452178067984
# trades: 459
# Resultado de sobre ajuste -1.1144019859126084
# Optimizando ventana: 2025-09-29 al 2025-10-24
# Resultado obtenido entrenando desde 2025-09-29 hasta 2025-10-24
# Método: WMA, Datos optimizados [np.int64(11), np.int64(9)]
#
# hit ratio: 0.714765100671141
# risk reward: 0.47729515614840856
# profit factor: 1.2102841459477502
# trades: 298
# Resultado de sobre ajuste -0.003504096694657565
# Optimizando ventana: 2025-10-06 al 2025-10-31
# Resultado obtenido entrenando desde 2025-10-06 hasta 2025-10-31
# Método: DEMA, Datos optimizados [np.int64(1), np.int64(39)]
#
# hit ratio: 0.7408552292632664
# risk reward: 0.3577780974414095
# profit factor: 1.1064191486467674
# trades: 1941
# Resultado de sobre ajuste 0.2895623234520788
# Optimizando ventana: 2025-10-13 al 2025-11-07
# Resultado obtenido entrenando desde 2025-10-13 hasta 2025-11-07
# Método: KAMA, Datos optimizados [np.int64(18), np.int64(35)]
#
# hit ratio: 0.835820895522388
# risk reward: 0.23425994108983814
# profit factor: 1.3118556701030937
# trades: 67
# Resultado de sobre ajuste 0.5752691457882793
# Optimizando ventana: 2025-10-20 al 2025-11-14
# Resultado obtenido entrenando desde 2025-10-20 hasta 2025-11-14
# Método: T3, Datos optimizados [np.int64(17), np.int64(49)]
#
# hit ratio: 0.8035714285714286
# risk reward: 0.4213333333333329
# profit factor: 2.1066666666666642
# trades: 56
# Resultado de sobre ajuste 0.10802943567800495
# Optimizando ventana: 2025-10-27 al 2025-11-21
# Resultado obtenido entrenando desde 2025-10-27 hasta 2025-11-21
# Método: WMA, Datos optimizados [np.int64(8), np.int64(83)]
#
# hit ratio: 0.7843137254901961
# risk reward: 0.28668846065611236
# profit factor: 1.2286648313833386
# trades: 153
# Resultado de sobre ajuste -0.4277255874975005
# Optimizando ventana: 2025-11-03 al 2025-11-28
# Resultado obtenido entrenando desde 2025-11-03 hasta 2025-11-28
# Método: TEMA, Datos optimizados [np.int64(11), np.int64(106)]
#
# hit ratio: 0.7818181818181819
# risk reward: 0.4401397832295901
# profit factor: 1.5771675565726981
# trades: 110
# Resultado de sobre ajuste 1.4155693931869886
# Optimizando ventana: 2025-11-10 al 2025-12-05
# Resultado obtenido entrenando desde 2025-11-10 hasta 2025-12-05
# Método: EMA, Datos optimizados [np.int64(16), np.int64(106)]
#
# hit ratio: 0.864406779661017
# risk reward: 0.3436073059360605
# profit factor: 2.503424657534155
# trades: 59
# Resultado de sobre ajuste 0.2893015756769728
# Optimizando ventana: 2025-11-17 al 2025-12-12
# Resultado obtenido entrenando desde 2025-11-17 hasta 2025-12-12
# Método: T3, Datos optimizados [np.int64(17), np.int64(64)]
#
# hit ratio: 0.8378378378378378
# risk reward: 1.7336890613630955
# profit factor: 8.957393483709327
# trades: 37
# Resultado de sobre ajuste 1.7352709544509093
# Optimizando ventana: 2025-11-24 al 2025-12-19
# Resultado obtenido entrenando desde 2025-11-24 hasta 2025-12-19
# Método: SMA, Datos optimizados [np.int64(19), np.int64(72)]
#
# hit ratio: 0.84375
# risk reward: 1.7494089834518707
# profit factor: 15.744680851066835
# trades: 64
# Resultado de sobre ajuste 0.9878819984705145
# Optimizando ventana: 2025-12-01 al 2025-12-26
# Resultado obtenido entrenando desde 2025-12-01 hasta 2025-12-26
# Método: T3, Datos optimizados [np.int64(12), np.int64(107)]
#
# hit ratio: 0.8717948717948718
# risk reward: 6.3103879849879085
# profit factor: 53.63829787239722
# trades: 39
# Resultado de sobre ajuste 1.5372427098034005
# Optimizando ventana: 2025-12-08 al 2026-01-02
# Resultado obtenido entrenando desde 2025-12-08 hasta 2026-01-02
# Método: WMA, Datos optimizados [np.int64(10), np.int64(104)]
#
# hit ratio: 0.8235294117647058
# risk reward: 0.3848085631947265
# profit factor: 2.0720461095100657
# trades: 85
# Resultado de sobre ajuste 0.6170945274829993
# Optimizando ventana: 2025-12-15 al 2026-01-09
# Resultado obtenido entrenando desde 2025-12-15 hasta 2026-01-09
# Método: TRIMA, Datos optimizados [np.int64(14), np.int64(77)]
#
# hit ratio: 0.8166666666666667
# risk reward: 0.32590222933118446
# profit factor: 1.596920923722804
# trades: 60
# Resultado de sobre ajuste 0.7947436497901068
# Optimizando ventana: 2025-12-22 al 2026-01-16
# Resultado obtenido entrenando desde 2025-12-22 hasta 2026-01-16
# Método: T3, Datos optimizados [np.int64(10), np.int64(14)]
#
# hit ratio: 0.6946107784431138
# risk reward: 0.40714963619109346
# profit factor: 1.0495412844037075
# trades: 167
# Resultado de sobre ajuste 0.01599993984648066
# Optimizando ventana: 2025-12-29 al 2026-01-23
# Resultado obtenido entrenando desde 2025-12-29 hasta 2026-01-23
# Método: DEMA, Datos optimizados [np.int64(5), np.int64(107)]
#
# hit ratio: 0.8101851851851852
# risk reward: 0.3044044923048502
# profit factor: 1.3317696538337198
# trades: 216
# Resultado de sobre ajuste 0.8093387457873868
# Optimizando ventana: 2026-01-05 al 2026-01-30
# Resultado obtenido entrenando desde 2026-01-05 hasta 2026-01-30
# Método: EMA, Datos optimizados [np.int64(20), np.int64(10)]
#
# hit ratio: 0.722972972972973
# risk reward: 0.6917089330003369
# profit factor: 1.8503213957759013
# trades: 148
# Resultado de sobre ajuste 1.7330624207597844
# Optimizando ventana: 2026-01-12 al 2026-02-06
# Resultado obtenido entrenando desde 2026-01-12 hasta 2026-02-06
# Método: DEMA, Datos optimizados [np.int64(13), np.int64(27)]
#
# hit ratio: 0.7611111111111111
# risk reward: 0.4533617229067662
# profit factor: 1.4788227628149282
# trades: 180
# Resultado de sobre ajuste 1.1174421877845022
# Optimizando ventana: 2026-01-19 al 2026-02-13
# Resultado obtenido entrenando desde 2026-01-19 hasta 2026-02-13
# Método: EMA, Datos optimizados [np.int64(12), np.int64(105)]
#
# hit ratio: 0.8611111111111112
# risk reward: 0.3301016886287833
# profit factor: 2.0466304694984565
# trades: 72
# Resultado de sobre ajuste 1.1733394009982843
